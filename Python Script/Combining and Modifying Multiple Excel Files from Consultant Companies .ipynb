# %% [markdown]
# # Summary for Initial Setup and Imports

# %%
import pandas as pd
import os
import re
import numpy as np
import warnings

warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl")

# %% [markdown]
# Description:
#
# Library Imports: This section imports essential Python libraries needed for the project.
#
# **pandas**: Used for data manipulation and analysis.
#
# **os**: Provides a way of using operating system dependent functionality.
#
# **re**: Allows for regular expression operations.
#
# **numpy**: Adds support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays.
#
#
# warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl"): Configures the script to ignore specific warnings, particularly those related to openpyxl, which is a library used for reading Excel files.

# %% [markdown]
# # Summary for File Path Configuration

# %%
path = "C:/Users/zkarimib@volvocars.com/OneDrive - Volvo Cars/Zohreh/Consultant Supplier Quality/Counsultant Supplier/Excel File/Company Excel LTI reports/All Consultant Company/231113/"
input_path = path + "in" + "/"
output_path = path + "out" + "/"
filter_path = path + "filter" + "/"
print(input_path)
# Out:
# C:/Users/zkarimib@volvocars.com/OneDrive - Volvo Cars/Zohreh/Consultant Supplier Quality/Counsultant Supplier/Excel File/Company Excel LTI reports/All Consultant Company/231113/in/

# %% [markdown]
# #### Base Path Setup
# - **`path` Variable**: Defined to store the base directory where all project-related files are located.
#
# #### Sub-directory Paths
# - **`input_path`**: Designated to hold the path for input files.
# - **`output_path`**: Set up for storing output files, which could include processed datasets, results from data analysis, or any exported data files.
# - **`filter_path`**: Used for storing files related to filtering criteria or other specific processing needs.

# %% [markdown]
# # Loading and Preparing Filter Data from Excel Files

# %% [markdown]
# **File Listing**: The script begins by listing all files in the input_path directory, helping to verify the available data files for processing.

# %%
file_list = os.listdir(input_path)
print(file_list)
# Out:
# ['accenture.xlsx', 'afry.xlsx', 'akkodis.xlsx', 'Alten.xlsx', 'amaris.xlsx', 'AVL.xlsx', 'broccoli.xlsx', 'caevalue.xlsx', 'cap-consult.xlsx', 'cap-eng.xlsx', 'combitech.xlsx', 'condesign.xlsx', 'consid.xlsx', 'devport.xlsx', 'diadrom.xlsx', 'edag.xlsx', 'epam.xlsx', 'etteplan.xlsx', 'evidente.xlsx', 'expleo.xlsx', 'FEV.xlsx', 'globallogic.xlsx', 'hcltech.xlsx', 'hiq.xlsx', 'knowit.xlsx', 'l-and-t.xlsx', 'luxoft.xlsx', 'mca.xlsx', 'Netgroup.xlsx', 'nexer.xlsx', 'qrtech.xlsx', 'Quokka.xlsx', 'segula.xlsx', 'semcon.xlsx', 'sigma.xlsx', 'tata-consult.xlsx', 'tata-tech.xlsx', 'techmahindra.xlsx', 'tieto.xlsx', 'togethertech.xlsx', 'tribuit.xlsx', 'Vinngroup.xlsx']

# %% [markdown]
# **Consultant Companies Data Processing**:
# Loads data from the "Consulting Firms.xlsx" file.
# Extracts unique consulting companies, applies regex escaping for special characters, and converts them to lowercase for consistent comparison.

# %%
consultant_filter_file = pd.read_excel(filter_path + "Consulting Firms.xlsx")
consultant_filter_list = consultant_filter_file['Consulting Company'].unique().tolist()
consultant_filter_list = [re.escape(item) for item in consultant_filter_list]
consultant_filter_list = sorted([element.lower() for element in consultant_filter_list])
#print(consultant_filter_list)

# %% [markdown]
# **Automotive Companies Data Processing:**
# Similar processing is applied to "Automotive Companies.xlsx", preparing a list of automotive companies.

# %%
# Load the Excel file for automative_company
automative_company_filter_file = pd.read_excel(filter_path + "Automotive Companies.xlsx")
automative_company_filter_list = automative_company_filter_file['Company'].tolist()
automative_company_filter_list = [re.escape(item) for item in automative_company_filter_list]
automative_company_filter_list = sorted([element.lower() for element in automative_company_filter_list])
#print(automative_company_filter_list)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 1.Sheet Name Checking Script
#
# ##### Initial Setup
# - The script starts by reading the first Excel file in the `input_path` directory and storing its sheet names in a set.
#
# ##### Iteration and Comparison
# - It then iterates through the rest of the Excel files in the directory.
# - For each file, it reads the sheet names and compares them with the sheet names of the first file.
#
# ##### Output
# - **Matching Sheet Names**: If the sheet names match those in the first file, it prints a confirmation message.
# - **Discrepancies in Sheet Names**: If there is a discrepancy in sheet names, it prints a message indicating which file has different sheets.

# %%
#Checking Sheet Names in Excel Files

first_file_path = os.path.join(input_path, file_list[0])
first_xls = pd.ExcelFile(first_file_path)
first_sheet_names = set(first_xls.sheet_names)

for file in file_list[1:]:
    file_path = os.path.join(input_path, file)
    xls = pd.ExcelFile(file_path)
    sheet_names = set(xls.sheet_names)
    
    if sheet_names == first_sheet_names:
        print(f"Sheets are the same as in the first file.")
    else:
        print(f"Sheets in {file} are different from the first file.")
# Out:
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.
# Sheets are the same as in the first file.

# %% [markdown]
# ### Results of Sheet Name Comparison
#
# - **Consistency in Sheet Names**: It was found that all the Excel files have the same sheet names as the first file. This consistency was confirmed for each file processed by the script.

# %% [markdown]
# ### 2. Listing Sheet Names in an Excel File
#
# The script segment below is designed to list the names of the sheets present in the first Excel file located in the `input_path`.

# %%
sheets_list = pd.ExcelFile(input_path + file_list[0])
print(sheets_list.sheet_names)
# Out:
# ['Overview', 'Locations', 'Company Movements', 'Location Movements', 'Industry Movements', 'Titles', 'Skills', 'Attrition by Functions', 'Attrition by Locations', 'Schools', 'Degrees', 'Fields of Study']

# %% [markdown]
# ### 3.Displaying Column Names for Each Sheet in an Excel File
#
# This script section lists the names of all columns for each sheet in the first Excel file within the `input_path`.

# %%
for sheet_name in sheets_list.sheet_names:
     df = pd.read_excel(os.path.join(input_path, file_list[0]), sheet_name)
     #print(f"Columns for sheet '{sheet_name}': {df.columns.tolist()}")

# %% [markdown]
# ### Functionality of the Column Name Listing Script
#
# #### Looping Through Sheets
# - The script iterates over each sheet name in `sheets_list.sheet_names`.
#
# #### Reading Each Sheet
# - For each sheet, it reads the data into a DataFrame `df` using `pd.read_excel`, specifying the sheet name.
#
# #### Printing Column Names
# - The column names of each DataFrame are then printed. This is done by accessing the `columns` attribute of `df`, converting it to a list, and printing it along with the sheet name.
#
# ### Purpose of the Script
#
# - This process is crucial for gaining an overview of the data structure within each sheet of the Excel file.
# - It helps in identifying which columns are available for analysis or need processing in subsequent steps.

# %% [markdown]
# ### 4.Displaying Column Names for Each Sheet in Every Excel File
#
# This script section lists the names of all columns for each sheet in every Excel file located in the `input_path`.

# %%
#The name of columns for each sheets and each file


for file_name in file_list:
    excel_file = pd.ExcelFile(os.path.join(input_path, file_name))
    sheets_list = excel_file.sheet_names

    for sheet_name in sheets_list:
        sheet_temp = excel_file.parse(sheet_name)
        #print(f"Columns for sheet '{sheet_name}' in file '{file_name}': \n{sheet_temp.columns}\n")

# %% [markdown]
# ### Purpose:
#
# This process provides a comprehensive overview of the data structure in every sheet of each Excel file in the directory.
# It's instrumental in understanding the variety and consistency of data columns across multiple files and sheets.
# This level of detail is particularly useful in projects that involve complex data sets spread across numerous files, ensuring thoroughness in data analysis and preprocessing.

# %% [markdown]
# ### 5.Displaying First Five Rows for Each Sheet in All Excel Files
#
# The following script segment is designed to display the first five rows of data for each sheet in all Excel files within the `input_path`.

# %%
for file_name in file_list:
    excel_file = pd.ExcelFile(os.path.join(input_path, file_name))
    sheets_list = excel_file.sheet_names

    for sheet_name in sheets_list:
        sheet_temp = excel_file.parse(sheet_name)
       
        print(f"5 head row for '{sheet_name}' in file '{file_name}': \n{sheet_temp.head()}\n")
# Out:
# 5 head row for 'Overview' in file 'accenture.xlsx':
#                               se-cr-accenture-231113 Unnamed: 1 Unnamed: 2
# 0                                     Company Report        NaN        NaN
# 1                             Created on: 11/13/2023        NaN        NaN
# 2                              Created by Megan Reif        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4  For internal distribution only. All use subjec...        NaN        NaN
#
# 5 head row for 'Locations' in file 'accenture.xlsx':
#                                Location  Employees  1y growth  1y hires  \
# 0   Greater Stockholm Metropolitan Area        228  -0.017241        38
# 1  Greater Gothenburg Metropolitan Area         34  -0.081081         6
# 2       Greater Malmö Metropolitan Area         20   0.176471         5
# 3        Täby, Stockholm County, Sweden          8   0.000000         1
# 4     Greater Uppsala Metropolitan Area          5  -0.285714         2
#
#    Job posts  % of employees    Your %
# 0          4        0.745098  0.053238
# 1          0        0.111111  0.837493
# 2          0        0.065359  0.032117
# 3          0        0.026144  0.000698
# 4          0        0.016340  0.002967
#
# 5 head row for 'Company Movements' in file 'accenture.xlsx':
#                      Company  Departures  Hires  Ratio  Net change
# 0                         EY           2      3    1.5           1
# 1                   Netlight           3      0   -3.0          -3
# 2                 Volvo Cars           3      0   -3.0          -3
# 3  Tata Consultancy Services           0      2    2.0           2
# 4           Capgemini Invent           1      1    1.0           0
#
# 5 head row for 'Location Movements' in file 'accenture.xlsx':
#                                Location  Departures  Hires     Ratio  \
# 0   Greater Stockholm Metropolitan Area          40     38 -1.052632
# 1  Greater Gothenburg Metropolitan Area          10      6 -1.666667
# 2       Greater Malmö Metropolitan Area           3      5  1.666667
# 3     Greater Uppsala Metropolitan Area           4      2 -2.000000
# 4             Luleå, Norrbotten, Sweden           2      2  1.000000
#
#    Net change
# 0          -2
# 1          -4
# 2           2
# 3          -2
# 4           0
#
# 5 head row for 'Industry Movements' in file 'accenture.xlsx':
#                             Industry  Departures  Hires  Ratio  Net change
# 0  Information Technology & Services          11      8 -1.375          -3
# 1              Management Consulting           2      7  3.500           5
# 2                         Automotive           6      2 -3.000          -4
# 3                         Accounting           2      3  1.500           1
# 4                   Higher Education           2      2  1.000           0
#
# 5 head row for 'Titles' in file 'accenture.xlsx':
#                          Titles  Employees  1y growth  1y hires  Job posts  \
# 0             Associate Manager         14  -0.066667         2          0
# 1           Strategy Consultant         14   0.000000         0          0
# 2                Senior Manager         12  -0.142857         0          0
# 3  Business Integration Manager         11   0.375000         1          0
# 4            Management Analyst         11   0.222222         2          0
#
#    % of employees    Your %
# 0        0.045752  0.000000
# 1        0.045752  0.000000
# 2        0.039216  0.002095
# 3        0.035948  0.000000
# 4        0.035948  0.000000
#
# 5 head row for 'Skills' in file 'accenture.xlsx':
#                           Skills  Employees  1y growth  1y hires  Job posts  \
# 0           Software Development        123  -0.082090        16          3
# 1                           Java        102  -0.055556        17          1
# 2  Python (Programming Language)         97  -0.039604        29          0
# 3                            SQL         89  -0.082474        15          0
# 4                    Engineering         84   0.012048        15          2
#
#    % of employees    Your %
# 0        0.401961  0.333566
# 1        0.333333  0.192529
# 2        0.316993  0.264444
# 3        0.290850  0.130040
# 4        0.274510  0.549660
#
# 5 head row for 'Attrition by Functions' in file 'accenture.xlsx':
#                  Function  Attrition  Your attrition  % of employees
# 0             Engineering   0.210526        0.095893        0.209150
# 1  Information Technology   0.179104        0.137625        0.209150
# 2    Business Development   0.052174        0.145985        0.199346
# 3              Consulting   0.285714        0.148148        0.068627
# 4              Operations   0.114286        0.165121        0.058824
#
# 5 head row for 'Attrition by Locations' in file 'accenture.xlsx':
#                                Location  Attrition  Your attrition  \
# 0   Greater Stockholm Metropolitan Area   0.173913        0.150495
# 1  Greater Gothenburg Metropolitan Area   0.281690        0.115924
# 2       Greater Malmö Metropolitan Area   0.162162        0.132964
#
#    % of employees
# 0        0.745098
# 1        0.111111
# 2        0.065359
#
# 5 head row for 'Schools' in file 'accenture.xlsx':
#                              Schools  Employees  1y growth  1y hires  \
# 0  KTH Royal Institute of Technology         76  -0.012987        12
# 1  Chalmers University of Technology         29   0.208333         8
# 2               Linköping University         28   0.120000         6
# 3               Stockholm University         26  -0.071429         3
# 4                 Uppsala University         24  -0.076923         3
#
#    % of employees    Your %
# 0        0.248366  0.035608
# 1        0.094771  0.307209
# 2        0.091503  0.034910
# 3        0.084967  0.006284
# 4        0.078431  0.015360
#
# 5 head row for 'Degrees' in file 'accenture.xlsx':
#                           Unnamed: 0  Accenture  Industry  Your company
# 0  Master of Business Administration   0.185841  0.146569      0.060962
# 1                    Master's Degree   0.566372  0.594803      0.614817
# 2                 Associate's Degree   0.004425  0.003654      0.003827
# 3                  Bachelor's Degree   0.225664  0.204628      0.262985
# 4               Doctor of Philosophy   0.017699  0.050345      0.057408
#
# 5 head row for 'Fields of Study' in file 'accenture.xlsx':
#                      Fields of study  Employees  1y growth  1y hires  \
# 0             Information Technology         49  -0.057692         5
# 1                   Computer Science         48   0.021277         9
# 2              Computational Science         44   0.000000         7
# 3  Engineering/Industrial Management         42   0.235294        13
# 4             Mechanical Engineering         23   0.000000         5
#
#    % of employees    Your %
# 0        0.160131  0.043638
# 1        0.156863  0.084133
# 2        0.143791  0.071740
# 3        0.137255  0.015011
# 4        0.075163  0.144702
#
# 5 head row for 'Overview' in file 'afry.xlsx':
#                                    se-cr-afry-231113 Unnamed: 1 Unnamed: 2
# 0                                     Company Report        NaN        NaN
# 1                             Created on: 11/13/2023        NaN        NaN
# 2                              Created by Megan Reif        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4  For internal distribution only. All use subjec...        NaN        NaN
#
# 5 head row for 'Locations' in file 'afry.xlsx':
#                                       Location  Employees  1y growth  \
# 0          Greater Stockholm Metropolitan Area        762  -0.006519
# 1         Greater Gothenburg Metropolitan Area        667  -0.008915
# 2              Greater Malmö Metropolitan Area        288  -0.027027
# 3            Greater Uppsala Metropolitan Area        123   0.042373
# 4  Trollhättan, Vastra Gotaland County, Sweden         90   0.168831
#
#    1y hires  Job posts  % of employees    Your %
# 0       141         38        0.257606  0.053238
# 1       114         54        0.225490  0.837493
# 2        50         19        0.097363  0.032117
# 3        20         10        0.041582  0.002967
# 4        19          8        0.030426  0.013789
#
# 5 head row for 'Company Movements' in file 'afry.xlsx':
#         Company  Departures  Hires     Ratio  Net change
# 0         Sweco          11     19  1.727273           8
# 1    Volvo Cars           9     14  1.555556           5
# 2  Scania Group          15      7 -2.142857          -8
# 3       Rejlers          15      4 -3.750000         -11
# 4       Ramboll           5      7  1.400000           2
#
# 5 head row for 'Location Movements' in file 'afry.xlsx':
#                                Location  Departures  Hires     Ratio  \
# 0   Greater Stockholm Metropolitan Area         153    141 -1.085106
# 1  Greater Gothenburg Metropolitan Area         120    114 -1.052632
# 2       Greater Malmö Metropolitan Area          56     50 -1.120000
# 3     Greater Uppsala Metropolitan Area          15     20  1.333333
# 4     Karlstad, Varmland County, Sweden          18     14 -1.285714
#
#    Net change
# 0         -12
# 1          -6
# 2          -6
# 3           5
# 4          -4
#
# 5 head row for 'Industry Movements' in file 'afry.xlsx':
#                                Industry  Departures  Hires     Ratio  \
# 0     Information Technology & Services          96     68 -1.411765
# 1                            Automotive          52     57  1.096154
# 2                     Civil Engineering          31     27 -1.148148
# 3  Mechanical Or Industrial Engineering          30     19 -1.578947
# 4             Government Administration          20     16 -1.250000
#
#    Net change
# 0         -28
# 1           5
# 2          -4
# 3         -11
# 4          -4
#
# 5 head row for 'Titles' in file 'afry.xlsx':
#                 Titles  Employees  1y growth  1y hires  Job posts  \
# 0           Consultant        243   0.004132        49          2
# 1      Project Manager        184  -0.036649        30          5
# 2  Automation Engineer         94   0.068182        25          5
# 3    Software Engineer         86  -0.033708        16          1
# 4     Process Engineer         63   0.211538        22          2
#
#    % of employees    Your %
# 0        0.082150  0.004189
# 1        0.062204  0.010822
# 2        0.031778  0.000175
# 3        0.029074  0.078373
# 4        0.021298  0.001920
#
# 5 head row for 'Skills' in file 'afry.xlsx':
#                         Skills  Employees  1y growth  1y hires  Job posts  \
# 0                  Engineering       1866  -0.014263       299        170
# 1                      AutoCAD        769  -0.015365       126          6
# 2                       MATLAB        675   0.019637       155          5
# 3  Computer-Aided Design (CAD)        654   0.006154       114         13
# 4          Product Development        652  -0.026866       103          9
#
#    % of employees    Your %
# 0        0.630832  0.549660
# 1        0.259973  0.076977
# 2        0.228195  0.297609
# 3        0.221095  0.145750
# 4        0.220419  0.330948
#
# 5 head row for 'Attrition by Functions' in file 'afry.xlsx':
#                          Function  Attrition  Your attrition  % of employees
# 0                     Engineering   0.192625        0.095893        0.388776
# 1                      Operations   0.139130        0.165121        0.159229
# 2                      Consulting   0.203443        0.148148        0.107505
# 3  Program and Project Management   0.206148        0.082902        0.091278
# 4          Information Technology   0.218182        0.137625        0.062880
#
# 5 head row for 'Attrition by Locations' in file 'afry.xlsx':
#                                       Location  Attrition  Your attrition  \
# 0          Greater Stockholm Metropolitan Area   0.200131        0.150495
# 1         Greater Gothenburg Metropolitan Area   0.179104        0.115924
# 2              Greater Malmö Metropolitan Area   0.191781        0.132964
# 3            Greater Uppsala Metropolitan Area   0.124481             NaN
# 4  Trollhättan, Vastra Gotaland County, Sweden   0.023952        0.040268
#
#    % of employees
# 0        0.257606
# 1        0.225490
# 2        0.097363
# 3        0.041582
# 4        0.030426
#
# 5 head row for 'Schools' in file 'afry.xlsx':
#                                          Schools  Employees  1y growth  \
# 0              KTH Royal Institute of Technology        371   0.033426
# 1              Chalmers University of Technology        353  -0.030220
# 2  The Faculty of Engineering at Lund University        174  -0.027933
# 3                             Uppsala University        155   0.000000
# 4                 Luleå University of Technology        139  -0.041379
#
#    1y hires  % of employees    Your %
# 0        69        0.125423  0.035608
# 1        57        0.119337  0.307209
# 2        30        0.058824  0.028801
# 3        38        0.052400  0.015360
# 4        25        0.046991  0.017630
#
# 5 head row for 'Degrees' in file 'afry.xlsx':
#                           Unnamed: 0      AFRY  Industry  Your company
# 0  Master of Business Administration  0.058172  0.056010      0.060962
# 1                    Master's Degree  0.635042  0.563084      0.614817
# 2                 Associate's Degree  0.004155  0.006071      0.003827
# 3                  Bachelor's Degree  0.249307  0.335520      0.262985
# 4               Doctor of Philosophy  0.053324  0.039315      0.057408
#
# 5 head row for 'Fields of Study' in file 'afry.xlsx':
#                                      Fields of study  Employees  1y growth  \
# 0                             Mechanical Engineering        293   0.003425
# 1             Electrical and Electronics Engineering        186  -0.010638
# 2          Design and Visual Communications, General        145   0.006944
# 3  Mechatronics, Robotics, and Automation Enginee...        116  -0.033333
# 4                                   Computer Science        111  -0.051282
#
#    1y hires  % of employees    Your %
# 0        54        0.099053  0.144702
# 1        31        0.062880  0.100890
# 2        34        0.049020  0.041194
# 3        21        0.039216  0.064758
# 4        18        0.037525  0.084133
# 5 head row for 'Overview' in file 'akkodis.xlsx':
#                                 se-cr-akkodis-231113 Unnamed: 1 Unnamed: 2
# 0                                     Company Report        NaN        NaN
# 1                             Created on: 11/13/2023        NaN        NaN
# 2                              Created by Megan Reif        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4  For internal distribution only. All use subjec...        NaN        NaN
#
# 5 head row for 'Locations' in file 'akkodis.xlsx':
#                                   Location  Employees  1y growth  1y hires  \
# 0     Greater Gothenburg Metropolitan Area          8   0.333333         3
# 1       Greater Västerås Metropolitan Area          6   0.500000         4
# 2  Eskilstuna, Sodermanland County, Sweden          2   0.000000         1
# 3          Greater Malmö Metropolitan Area          1        NaN         1
# 4          Varberg, Halland County, Sweden          1   0.000000         0
#
#    Job posts  % of employees    Your %
# 0          1        0.347826  0.837493
# 1          2        0.260870  0.000000
# 2          0        0.086957  0.000000
# 3          0        0.043478  0.032117
# 4          0        0.043478  0.002269
#
# 5 head row for 'Company Movements' in file 'akkodis.xlsx':
#                        Company  Departures  Hires  Ratio  Net change
# 0                        Modis           0      4      4           4
# 1                    Northvolt           1      1      1           0
# 2  Randstad Engineering Sweden           0      1      1           1
# 3                        ALTEN           0      1      1           1
# 4         Our Space Appliances           0      1      1           1
#
# 5 head row for 'Location Movements' in file 'akkodis.xlsx':
#                                Location  Departures  Hires  Ratio  Net change
# 0    Greater Västerås Metropolitan Area           2      4      2           2
# 1  Greater Gothenburg Metropolitan Area           1      3      3           2
# 2        Avesta, Dalarna County, Sweden           0      1      1           1
# 3   Greater Stockholm Metropolitan Area           0      1      1           1
# 4       Greater Malmö Metropolitan Area           0      1      1           1
#
# 5 head row for 'Industry Movements' in file 'akkodis.xlsx':
#                                 Industry  Departures  Hires  Ratio  Net change
# 0      Information Technology & Services           0      4      4           4
# 1                  Staffing & Recruiting           0      2      2           2
# 2   Mechanical Or Industrial Engineering           1      1      1           0
# 3                 Hospital & Health Care           0      1      1           1
# 4  Electrical & Electronic Manufacturing           0      1      1           1
#
# 5 head row for 'Titles' in file 'akkodis.xlsx':
#                 Titles  Employees  1y growth  1y hires  Job posts  \
# 0           Consultant          5   0.250000         3          0
# 1     Business Manager          4   0.333333         1          0
# 2  Electrical Designer          1        NaN         1          0
# 3        Subcontractor          1        NaN         1          0
# 4   Software Architect          1   0.000000         0          0
#
#    % of employees    Your %
# 0        0.217391  0.004189
# 1        0.173913  0.000000
# 2        0.043478  0.000000
# 3        0.043478  0.000000
# 4        0.043478  0.004538
#
# 5 head row for 'Skills' in file 'akkodis.xlsx':
#                    Skills  Employees  1y growth  1y hires  Job posts  \
# 0             Engineering         16   0.333333         7          8
# 1  Mechanical Engineering          7   0.166667         2          3
# 2     Product Development          6   0.000000         1          0
# 3                     SQL          6   0.200000         3          1
# 4              SOLIDWORKS          5   0.000000         1          0
#
#    % of employees    Your %
# 0        0.695652  0.549660
# 1        0.304348  0.138942
# 2        0.260870  0.330948
# 3        0.260870  0.130040
# 4        0.217391  0.072962
#
# 5 head row for 'Attrition by Functions' in file 'akkodis.xlsx':
# Empty DataFrame
# Columns: [Function, Attrition, Your attrition, % of employees]
# Index: []
#
# 5 head row for 'Attrition by Locations' in file 'akkodis.xlsx':
# Empty DataFrame
# Columns: [Location, Attrition, Your attrition, % of employees]
# Index: []
#
# 5 head row for 'Schools' in file 'akkodis.xlsx':
#                              Schools  Employees  1y growth  1y hires  \
# 0              Mälardalen University          5        0.0         2
# 1               Linköping University          2        0.0         0
# 2                        YH Akademin          2        1.0         1
# 3             University of Khartoum          1        0.0         0
# 4  Chalmers University of Technology          1        NaN         1
#
#    % of employees    Your %
# 0        0.217391  0.004015
# 1        0.086957  0.034910
# 2        0.086957  0.003840
# 3        0.043478  0.000349
# 4        0.043478  0.307209
#
# 5 head row for 'Degrees' in file 'akkodis.xlsx':
#                           Unnamed: 0   Akkodis  Industry  Your company
# 0                    Master's Degree  0.769231  0.563084      0.614817
# 1                  Bachelor's Degree  0.230769  0.335520      0.262985
# 2  Master of Business Administration  0.000000  0.056010      0.060962
# 3                 Associate's Degree  0.000000  0.006071      0.003827
# 4               Doctor of Philosophy  0.000000  0.039315      0.057408
#
# 5 head row for 'Fields of Study' in file 'akkodis.xlsx':
#           Fields of study  Employees  1y growth  1y hires  % of employees  \
# 0  Mechanical Engineering          4        0.0         1        0.173913
# 1               Economics          3        0.5         2        0.130435
# 2             Engineering          2        1.0         1        0.086957
# 3      Energy Engineering          2        0.0         0        0.086957
# 4  Information Technology          2        1.0         1        0.086957
#
#      Your %
# 0  0.144702
# 1  0.016059
# 2  0.020073
# 3  0.002444
# 4  0.043638
#
# 5 head row for 'Overview' in file 'Alten.xlsx':
#                          se-cr-alten-globalse-231113 Unnamed: 1 Unnamed: 2  \
# 0                                     Company Report        NaN        NaN
# 1                             Created on: 11/13/2023        NaN        NaN
# 2                              Created by Megan Reif        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4  For internal distribution only. All use subjec...        NaN        NaN
#
#   se-cr-alten-swe-231113
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# 5 head row for 'Locations' in file 'Alten.xlsx':
#                                   Location  Employees  1y hires  Job posts  \
# 0         Askersund, Orebro County, Sweden          1         1          0
# 1         Borlänge, Dalarna County, Sweden          1         1          0
# 2    Borås, Vastra Gotaland County, Sweden          2         0          0
# 3  Eskilstuna, Sodermanland County, Sweden          1         0          0
# 4            Falun, Dalarna County, Sweden          1         1          0
#
#    N Last Year Employee    Your %  1 Year Growth  % of employees
# 0                   0.0  0.000000            NaN        0.001282
# 1                   1.0  0.000000            0.0        0.001282
# 2                   2.0  0.005062            0.0        0.002564
# 3                   2.0  0.000000           -0.5        0.001282
# 4                   0.0  0.000000            NaN        0.001282
#
# 5 head row for 'Company Movements' in file 'Alten.xlsx':
#                        Company  Departures  Hires  Net change  Ratio
# 0                           3M           0      1           1    1.0
# 1                          ABB           2      1          -1   -2.0
# 2                         AFRY           1      5           4    0.2
# 3           ALPS ALPINE Europe           2      0          -2   -2.0
# 4  ALTEN Delivery Centre Spain           0      2           2    2.0
#
# 5 head row for 'Location Movements' in file 'Alten.xlsx':
#                                   Location  Departures  Hires  Net change  \
# 0         Askersund, Orebro County, Sweden           0      1           1
# 1         Borlänge, Dalarna County, Sweden           1      1           0
# 2         Enköping, Uppsala County, Sweden           1      0          -1
# 3  Eskilstuna, Sodermanland County, Sweden           1      0          -1
# 4            Falun, Dalarna County, Sweden           0      1           1
#
#    Ratio
# 0    1.0
# 1    1.0
# 2   -1.0
# 3   -1.0
# 4    1.0
#
# 5 head row for 'Industry Movements' in file 'Alten.xlsx':
#                   Industry  Departures  Hires  Net change    Ratio
# 0  Architecture & Planning           0      1           1  1.00000
# 1               Automotive          55     43         -12 -1.27907
# 2     Aviation & Aerospace           2      4           2  0.50000
# 3                  Banking           3      1          -2 -3.00000
# 4            Biotechnology           0      3           3  3.00000
#
# 5 head row for 'Titles' in file 'Alten.xlsx':
#                   Titles  Employees  1y hires  Job posts  \
# 0    Analysis Consultant          1         0          0
# 1                Analyst          2         0          0
# 2      Android Developer          1         1          0
# 3  Automotive Consultant          2         1          0
# 4     Automotive Manager          1         0          0
#
#    N Last Year Employee    Your %  1 Year Growth  % of employees
# 0                   1.0  0.000000       0.000000        0.001395
# 1                   3.0  0.001222      -0.333333        0.002789
# 2                   0.0  0.003491            NaN        0.001395
# 3                   1.0  0.000175       1.000000        0.002789
# 4                   1.0  0.000000       0.000000        0.001395
#
# 5 head row for 'Skills' in file 'Alten.xlsx':
#            Skills  Employees  1y hires  Job posts  N Last Year Employee  \
# 0  .NET Framework         49        18          1                  49.0
# 1     3D Modeling         43        12          0                  48.0
# 2         ASP.NET         33        12          0                  33.0
# 3     ASP.NET MVC          5         2          0                   5.0
# 4          Abaqus         38        13          1                  33.0
#
#      Your %  1 Year Growth  % of employees
# 0  0.042765   7.664474e-10        0.006240
# 1  0.013964  -1.041667e-01        0.005476
# 2  0.019375  -5.959472e-09        0.004202
# 3  0.011346   0.000000e+00        0.000637
# 4  0.020597   1.515152e-01        0.004839
#
# 5 head row for 'Attrition by Functions' in file 'Alten.xlsx':
#                          Function  Attrition  Your attrition  % of employees  \
# 0                      Consulting   0.669480        0.148148        0.507680
# 1                     Engineering   0.707592        0.095893        0.909474
# 2          Information Technology   0.263158        0.137625        0.082153
# 3                      Operations   0.163265        0.165121        0.036827
# 4  Program and Project Management   0.325581        0.082902        0.025496
#
#    Departures  Average Employee  Attrition by Function
# 0   17.010641         50.768021               0.335066
# 1   31.781203         90.947434               0.349446
# 2    2.161921          8.215298               0.263158
# 3    0.601260          3.682720               0.163265
# 4    0.830094          2.549575               0.325581
#
# 5 head row for 'Attrition by Locations' in file 'Alten.xlsx':
#                                Location  Attrition  Your attrition  \
# 0  Greater Gothenburg Metropolitan Area   0.609507        0.115924
# 1   Greater Linköping Metropolitan Area   0.222222             NaN
# 2       Greater Malmö Metropolitan Area   0.129032        0.132964
# 3   Greater Stockholm Metropolitan Area   0.489104        0.150495
# 4    Greater Västerås Metropolitan Area   0.311111             NaN
#
#    % of employees  Departures  Average Employee  Attrition by Locations
# 0        0.746931   22.840598         74.693108                0.305793
# 1        0.083569    1.857098          8.356941                0.222222
# 2        0.043909    0.566572          4.390935                0.129032
# 3        0.578376   13.780875         57.837583                0.238269
# 4        0.029745    0.925401          2.974504                0.311111
#
# 5 head row for 'Schools' in file 'Alten.xlsx':
#                                              Schools  Employees  1y hires  \
# 0                               Ain Shams University          1         1
# 1                                  Aleppo University          1         1
# 2                              Alexandria University          4         0
# 3       Alma Mater Studiorum – Università di Bologna          2         0
# 4  American International School in Abu Dhabi (AISA)          1         1
#
#    N Last Year Employee    Your %  1 Year Growth  % of employees
# 0                   0.0  0.000698            NaN        0.001348
# 1                   0.0  0.000349            NaN        0.001348
# 2                   4.0  0.000524       0.000000        0.005391
# 3                   3.0  0.000349      -0.333333        0.002695
# 4                   0.0  0.000000            NaN        0.001348
#
# 5 head row for 'Degrees' in file 'Alten.xlsx':
#                               Degree   Company  Industry  Your company
# 0                 Associate's Degree  0.002193  0.006071      0.003827
# 1                  Bachelor's Degree  0.329032  0.335520      0.262985
# 2               Doctor of Philosophy  0.048583  0.039315      0.057408
# 3  Master of Business Administration  0.040317  0.056010      0.060962
# 4                    Master's Degree  0.579875  0.563084      0.614817
#
# 5 head row for 'Fields of Study' in file 'Alten.xlsx':
#                                      Fields of study  Employees  1y hires  \
# 0                             Accounting and Finance          1         0
# 1  Aeronautics/Aviation/Aerospace Science and Tec...          7         0
# 2  Aerospace, Aeronautical and Astronautical Engi...          3         0
# 3  Aerospace, Aeronautical and Astronautical/Spac...          9         4
# 4  Airframe Mechanics and Aircraft Maintenance Te...          1         0
#
#    N Last Year Employee    Your %  1 Year Growth  % of employees
# 0                   1.0  0.000698          0.000        0.000880
# 1                   8.0  0.002793         -0.125        0.006157
# 2                   5.0  0.002444         -0.400        0.002639
# 3                   6.0  0.005411          0.500        0.007916
# 4                   1.0  0.000175          0.000        0.000880
# 5 head row for 'Overview' in file 'amaris.xlsx':
#                                  se-cr-amaris-231113 Unnamed: 1 Unnamed: 2
# 0                                     Company Report        NaN        NaN
# 1                             Created on: 11/13/2023        NaN        NaN
# 2                              Created by Megan Reif        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4  For internal distribution only. All use subjec...        NaN        NaN
#
# 5 head row for 'Locations' in file 'amaris.xlsx':
#                                Location  Employees  1y growth  1y hires  \
# 0  Greater Gothenburg Metropolitan Area         29   -0.09375         8
# 1   Greater Stockholm Metropolitan Area          3    0.50000         2
# 2       Greater Malmö Metropolitan Area          2    0.00000         0
# 3      Skellefteå, Västerbotten, Sweden          1        NaN         1
# 4    Olofström, Blekinge County, Sweden          1        NaN         1
#
#    Job posts  % of employees    Your %
# 0          8        0.783784  0.837493
# 1          1        0.081081  0.053238
# 2          0        0.054054  0.032117
# 3          0        0.027027  0.000000
# 4          0        0.027027  0.004189
#
# 5 head row for 'Company Movements' in file 'amaris.xlsx':
#                               Company  Departures  Hires  Ratio  Net change
# 0  Bosch Global Software Technologies           0      3      3           3
# 1                         Volvo Group           2      1     -2          -1
# 2                          Volvo Cars           2      1     -2          -1
# 3                  NorthBay Solutions           0      2      2           2
# 4                                CEVT           1      1      1           0
#
# 5 head row for 'Location Movements' in file 'amaris.xlsx':
#                                Location  Departures  Hires  Ratio  Net change
# 0  Greater Gothenburg Metropolitan Area           9      8 -1.125          -1
# 1   Greater Stockholm Metropolitan Area           1      2  2.000           1
# 2    Olofström, Blekinge County, Sweden           0      1  1.000           1
# 3      Skellefteå, Västerbotten, Sweden           0      1  1.000           1
#
# 5 head row for 'Industry Movements' in file 'amaris.xlsx':
#                                 Industry  Departures  Hires  Ratio  Net change
# 0                             Automotive           6      2     -3          -4
# 1                      Computer Software           0      2      2           2
# 2      Information Technology & Services           1      1      1           0
# 3  Electrical & Electronic Manufacturing           0      1      1           1
# 4                         Graphic Design           0      1      1           1
#
# 5 head row for 'Titles' in file 'amaris.xlsx':
#                    Titles  Employees  1y growth  1y hires  Job posts  \
# 0               Site Lead          3        NaN         0          0
# 1  Engineering Consultant          3        2.0         2          0
# 2               Developer          2        0.0         0          0
# 3    Technical Consultant          2        0.0         1          0
# 4        Cloud Consultant          2        1.0         1          0
#
#    % of employees    Your %
# 0        0.081081  0.000000
# 1        0.081081  0.001222
# 2        0.054054  0.015360
# 3        0.054054  0.001222
# 4        0.054054  0.000000
#
# 5 head row for 'Skills' in file 'amaris.xlsx':
#                           Skills  Employees  1y growth  1y hires  Job posts  \
# 0                    Engineering         23   0.352941         9          9
# 1                     Automotive         17   0.062500         4          3
# 2  Python (Programming Language)         17  -0.260870         2          1
# 3           Software Development         16  -0.304348         2          4
# 4                         MATLAB         12   0.000000         2          1
#
#    % of employees    Your %
# 0        0.621622  0.549660
# 1        0.459459  0.434282
# 2        0.459459  0.264444
# 3        0.432432  0.333566
# 4        0.324324  0.297609
#
# 5 head row for 'Attrition by Functions' in file 'amaris.xlsx':
#       Function  Attrition  Your attrition  % of employees
# 0  Engineering   0.263158        0.095893        0.513514
#
# 5 head row for 'Attrition by Locations' in file 'amaris.xlsx':
#                                Location  Attrition  Your attrition  \
# 0  Greater Gothenburg Metropolitan Area   0.295082        0.115924
#
#    % of employees
# 0        0.783784
#
# 5 head row for 'Schools' in file 'amaris.xlsx':
#                                  Schools  Employees  1y growth  1y hires  \
# 0      Chalmers University of Technology         10   0.428571         3
# 1           Université de Caen Normandie          2   0.000000         0
# 2       Blekinge Institute of Technology          2   0.000000         0
# 3  Visvesvaraya Technological University          2   1.000000         1
# 4    Faculdade Israelita Albert Einstein          2   1.000000         1
#
#    % of employees    Your %
# 0        0.270270  0.307209
# 1        0.054054  0.000175
# 2        0.054054  0.021295
# 3        0.054054  0.009949
# 4        0.054054  0.000175
#
# 5 head row for 'Degrees' in file 'amaris.xlsx':
#                           Unnamed: 0  Amaris Consulting  Industry  \
# 0  Master of Business Administration           0.068966  0.056010
# 1                    Master's Degree           0.689655  0.563084
# 2                  Bachelor's Degree           0.241379  0.335520
# 3                 Associate's Degree           0.000000  0.006071
# 4               Doctor of Philosophy           0.000000  0.039315
#
#    Your company
# 0      0.060962
# 1      0.614817
# 2      0.262985
# 3      0.003827
# 4      0.057408
#
# 5 head row for 'Fields of Study' in file 'amaris.xlsx':
#                                      Fields of study  Employees  1y growth  \
# 0                             Mechanical Engineering          9   0.500000
# 1             Electrical and Electronics Engineering          6   0.200000
# 2                                        Engineering          5   4.000000
# 3                                   Computer Science          4  -0.428571
# 4  Electrical, Electronics and Communications Eng...          4   0.000000
#
#    1y hires  % of employees    Your %
# 0         5        0.243243  0.144702
# 1         1        0.162162  0.100890
# 2         4        0.135135  0.020073
# 3         1        0.108108  0.084133
# 4         1        0.108108  0.049921
#
# 5 head row for 'Overview' in file 'AVL.xlsx':
#                               se-cr-alvmtc-ab-231113 Unnamed: 1 Unnamed: 2  \
# 0                                     Company Report        NaN        NaN
# 1                             Created on: 11/13/2023        NaN        NaN
# 2                              Created by Megan Reif        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4  For internal distribution only. All use subjec...        NaN        NaN
#
#   se-cr-alvmtc-motor-231113 se-cr-avl-231113
# 0                       NaN              NaN
# 1                       NaN              NaN
# 2                       NaN              NaN
# 3                       NaN              NaN
# 4                       NaN              NaN
#
# 5 head row for 'Locations' in file 'AVL.xlsx':
#                                   Location  Employees  1y hires  Job posts  \
# 0        Bergsjö, Gavleborg County, Sweden          1         0          0
# 1  Eskilstuna, Sodermanland County, Sweden          1         0          0
# 2         Gnosjö, Jonkoping County, Sweden          1         0          0
# 3     Greater Gothenburg Metropolitan Area         25         4          3
# 4      Greater Stockholm Metropolitan Area         69         8          5
#
#    N Last Year Employee    Your %  1 Year Growth  % of employees
# 0              1.000000  0.000000       0.000000        0.009009
# 1              1.000000  0.000000       0.000000        0.009009
# 2              1.000000  0.000000       0.000000        0.009009
# 3             32.000000  0.837493      -0.218750        0.225225
# 4             77.000001  0.053238      -0.103896        0.621622
#
# 5 head row for 'Company Movements' in file 'AVL.xlsx':
#                  Company  Departures  Hires  Net change  Ratio
# 0           ALTEN Sweden           2      0          -2     -2
# 1            AstraZeneca           1      0          -1     -1
# 2                Boliden           1      0          -1     -1
# 3  Capgemini Engineering           0      2           2      2
# 4      Cascade Drives AB           1      0          -1     -1
#
# 5 head row for 'Location Movements' in file 'AVL.xlsx':
#                                 Location  Departures  Hires  Net change  Ratio
# 0         Avesta, Dalarna County, Sweden           1      0          -1  -1.00
# 1   Greater Gothenburg Metropolitan Area          11      4          -7  -2.75
# 2  Greater Helsingborg Metropolitan Area           2      0          -2  -2.00
# 3    Greater Stockholm Metropolitan Area          18      8         -10  -2.25
# 4           Mora, Dalarna County, Sweden           1      0          -1  -1.00
#
# 5 head row for 'Industry Movements' in file 'AVL.xlsx':
#                       Industry  Departures  Hires  Net change     Ratio
# 0            Airlines/Aviation           1      0          -1 -1.000000
# 1                   Automotive          17      6         -11 -2.833333
# 2  Computer & Network Security           0      2           2  2.000000
# 3            Computer Software           1      0          -1 -1.000000
# 4         Consumer Electronics           0      1           1  1.000000
#
# 5 head row for 'Titles' in file 'AVL.xlsx':
#                          Titles  Employees  1y hires  Job posts  \
# 0                  Area Manager          1         0          0
# 1            Assistant Designer          1         0          0
# 2  Business Development Manager          1         0          0
# 3              Business Manager          3         0          0
# 4          Calibration Engineer          4         1          1
#
#    N Last Year Employee    Your %  1 Year Growth  % of employees
# 0                   1.0  0.000000            0.0        0.008333
# 1                   1.0  0.003666            0.0        0.008333
# 2                   1.0  0.000175            0.0        0.008333
# 3                   3.0  0.000000            0.0        0.025000
# 4                   5.0  0.000873           -0.2        0.033333
#
# 5 head row for 'Skills' in file 'AVL.xlsx':
#          Skills  Employees  1y hires  Job posts  N Last Year Employee  \
# 0    2-D Design          1         0          0                   1.0
# 1            5S          6         0          0                   6.0
# 2        AMESim          1         0          0                   1.0
# 3     AVL Boost          1         0          0                   1.0
# 4  AVL Concerto          8         0          0                  12.0
#
#      Your %  1 Year Growth  % of employees
# 0  0.000175       0.000000        0.000796
# 1  0.049049       0.000000        0.004777
# 2  0.001571       0.000000        0.000796
# 3  0.000175       0.000000        0.000796
# 4  0.001047      -0.333333        0.006369
#
# 5 head row for 'Attrition by Functions' in file 'AVL.xlsx':
#       Function  Attrition  Your attrition  % of employees  Departures  \
# 0  Engineering   0.333333        0.095893        0.534653   17.821783
#
#    Average Employee  Attrition by Function
# 0         53.465348               0.333333
#
# 5 head row for 'Attrition by Locations' in file 'AVL.xlsx':
#                                Location  Attrition  Your attrition  \
# 0  Greater Gothenburg Metropolitan Area   0.385965        0.115924
# 1   Greater Stockholm Metropolitan Area   0.276923        0.150495
#
#    % of employees  Departures  Average Employee  Attrition by Locations
# 0        0.247525    9.553587         24.752475                0.385965
# 1        0.594059   16.450877         59.405941                0.276923
#
# 5 head row for 'Schools' in file 'AVL.xlsx':
#                                            Schools  Employees  1y hires  \
# 0                               Aalborg University          1         0
# 1                      Beijing Jiaotong University          2         1
# 2               Bialystok University of Technology          1         1
# 3                 Blekinge Institute of Technology          1         0
# 4  Budapest University of Technology and Economics          1         0
#
#    N Last Year Employee    Your %  1 Year Growth  % of employees
# 0                   1.0  0.001222            0.0        0.007194
# 1                   1.0  0.000524            1.0        0.014388
# 2                   0.0  0.000000            NaN        0.007194
# 3                   1.0  0.021295            0.0        0.007194
# 4                   1.0  0.000873            0.0        0.007194
#
# 5 head row for 'Degrees' in file 'AVL.xlsx':
#                               Degree   Company  Industry  Your company
# 0                 Associate's Degree  0.000000  0.003836      0.003827
# 1                  Bachelor's Degree  0.215152  0.249361      0.262985
# 2               Doctor of Philosophy  0.129293  0.066496      0.057408
# 3  Master of Business Administration  0.036364  0.078005      0.060962
# 4                    Master's Degree  0.619192  0.602302      0.614817
#
# 5 head row for 'Fields of Study' in file 'AVL.xlsx':
#                                      Fields of study  Employees  1y hires  \
# 0  Aerospace, Aeronautical and Astronautical/Spac...          1         0
# 1          Automation Engineer Technology/Technician          1         0
# 2  Automobile/Automotive Mechanics Technology/Tec...          3         0
# 3       Automotive Engineering Technology/Technician          4         0
# 4    Business Administration and Management, General          2         0
#
#    N Last Year Employee    Your %  1 Year Growth  % of employees
# 0                   1.0  0.005411       0.000000           0.008
# 1                   1.0  0.004015       0.000000           0.008
# 2                   4.0  0.012568      -0.250000           0.024
# 3                   6.0  0.032641      -0.333333           0.032
# 4                   2.0  0.021644       0.000000           0.016
#
# 5 head row for 'Overview' in file 'broccoli.xlsx':
#                                se-cr-broccoli-231113 Unnamed: 1 Unnamed: 2
# 0                                     Company Report        NaN        NaN
# 1                             Created on: 11/13/2023        NaN        NaN
# 2                              Created by Megan Reif        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4  For internal distribution only. All use subjec...        NaN        NaN
#
# 5 head row for 'Locations' in file 'broccoli.xlsx':
#                                       Location  Employees  1y growth  \
# 0         Greater Gothenburg Metropolitan Area         18   0.058824
# 1  Trollhättan, Vastra Gotaland County, Sweden          1  -0.500000
#
#    1y hires  Job posts  % of employees    Your %
# 0         2          0        0.947368  0.837493
# 1         0          0        0.052632  0.013789
#
# 5 head row for 'Company Movements' in file 'broccoli.xlsx':
#                            Company  Departures  Hires  Ratio  Net change
# 0  THE BLACK PEARL I KUNGSBACKA AB           0      1      1           1
# 1                       DevPort AB           0      1      1           1
# 2                      Nexer Group           1      0     -1          -1
# 3  ABTERY - Electric Drive Systems           1      0     -1          -1
#
# 5 head row for 'Location Movements' in file 'broccoli.xlsx':
#                                       Location  Departures  Hires  Ratio  \
# 0         Greater Gothenburg Metropolitan Area           1      2      2
# 1  Trollhättan, Vastra Gotaland County, Sweden           1      0     -1
#
#    Net change
# 0           1
# 1          -1
#
# 5 head row for 'Industry Movements' in file 'broccoli.xlsx':
#                             Industry  Departures  Hires  Ratio  Net change
# 0  Information Technology & Services           1      1      1           0
# 1                         Automotive           1      1      1           0
#
# 5 head row for 'Titles' in file 'broccoli.xlsx':
#               Titles  Employees  1y growth  1y hires  Job posts  \
# 0         Consultant          9      0.125         1          0
# 1            Manager          2      0.000         0          0
# 2      Test Engineer          1      0.000         0          0
# 3  Software Engineer          1        NaN         1          0
# 4           Engineer          1     -0.500         0          0
#
#    % of employees    Your %
# 0        0.473684  0.004189
# 1        0.105263  0.012568
# 2        0.052632  0.009949
# 3        0.052632  0.078373
# 4        0.052632  0.013091
#
# 5 head row for 'Skills' in file 'broccoli.xlsx':
#                  Skills  Employees  1y growth  1y hires  Job posts  \
# 0           Programming         10   0.111111         1          0
# 1      Embedded Systems          9   0.000000         0          0
# 2  Software Development          8   0.000000         0          0
# 3     Embedded Software          7   0.000000         0          0
# 4   Product Development          7  -0.125000         0          0
#
#    % of employees    Your %
# 0        0.526316  0.135975
# 1        0.473684  0.161983
# 2        0.421053  0.333566
# 3        0.368421  0.103508
# 4        0.368421  0.330948
#
# 5 head row for 'Attrition by Functions' in file 'broccoli.xlsx':
# Empty DataFrame
# Columns: [Function, Attrition, Your attrition, % of employees]
# Index: []
#
# 5 head row for 'Attrition by Locations' in file 'broccoli.xlsx':
#                                Location  Attrition  Your attrition  \
# 0  Greater Gothenburg Metropolitan Area   0.057143        0.115924
#
#    % of employees
# 0        0.947368
#
# 5 head row for 'Schools' in file 'broccoli.xlsx':
#                              Schools  Employees  1y growth  1y hires  \
# 0  Chalmers University of Technology         13   0.083333         2
# 1                University of Borås          1   0.000000         0
# 2                 Tunghai University          1   0.000000         0
# 3                     Ege University          1   0.000000         0
# 4              Mid Sweden University          1   0.000000         0
#
#    % of employees    Your %
# 0        0.684211  0.307209
# ...
# 0                             Mechanical Engineering         25   0.136364
# 1             Electrical and Electronics Engineering         13   0.000000
# 2          Design and Visual Communications, General         10  -0.090909
# 3  Mechatronics, Robotics, and Automation Enginee...          9   0.125000
# 4  Electrical, Electronics and Communications Eng...          7   0.750000
#
#    1y hires  % of employees    Your %
# 0        10        0.204918  0.144702
# 1         2        0.106557  0.100890
# 2         0        0.081967  0.041194
# 3         2        0.073770  0.064758
# 4         3        0.057377  0.049921
#
# 5 head row for 'Overview' in file 'tribuit.xlsx':
#                                 se-cr-tribuit-231113 Unnamed: 1 Unnamed: 2
# 0                                     Company Report        NaN        NaN
# 1                             Created on: 11/13/2023        NaN        NaN
# 2                              Created by Megan Reif        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4  For internal distribution only. All use subjec...        NaN        NaN
#
# 5 head row for 'Locations' in file 'tribuit.xlsx':
#                                Location  Employees  1y growth  1y hires  \
# 0  Greater Gothenburg Metropolitan Area          8   0.142857         1
#
#    Job posts  % of employees    Your %
# 0          0               1  0.837493
#
# 5 head row for 'Company Movements' in file 'tribuit.xlsx':
# Empty DataFrame
# Columns: [Company, Departures, Hires, Ratio, Net change]
# Index: []
#
# 5 head row for 'Location Movements' in file 'tribuit.xlsx':
#                                Location  Departures  Hires  Ratio  Net change
# 0  Greater Gothenburg Metropolitan Area           0      1      1           1
#
# 5 head row for 'Industry Movements' in file 'tribuit.xlsx':
# Empty DataFrame
# Columns: [Industry, Departures, Hires, Ratio, Net change]
# Index: []
#
# 5 head row for 'Titles' in file 'tribuit.xlsx':
#                                               Titles  Employees  1y growth  \
# 0                                Electrical Engineer          1        0.0
# 1  Information Technology Project Management Cons...          1        NaN
# 2                                  Software Engineer          1        0.0
# 3                                            Partner          1        0.0
# 4                        Senior Technical Consultant          1        0.0
#
#    1y hires  Job posts  % of employees    Your %
# 0         0          0           0.125  0.001222
# 1         1          0           0.125  0.000000
# 2         0          0           0.125  0.078373
# 3         0          0           0.125  0.000000
# 4         0          0           0.125  0.000000
#
# 5 head row for 'Skills' in file 'tribuit.xlsx':
#                    Skills  Employees  1y growth  1y hires  Job posts  \
# 0        Embedded Systems          7        0.0         0          0
# 1              Automotive          6        0.0         0          0
# 2    Software Development          6        0.0         0          0
# 3       Embedded Software          6        0.0         0          0
# 4  Automotive Engineering          5        0.0         0          0
#
#    % of employees    Your %
# 0           0.875  0.161983
# 1           0.750  0.434282
# 2           0.750  0.333566
# 3           0.750  0.103508
# 4           0.625  0.229709
#
# 5 head row for 'Attrition by Functions' in file 'tribuit.xlsx':
# Empty DataFrame
# Columns: [Function, Attrition, Your attrition, % of employees]
# Index: []
#
# 5 head row for 'Attrition by Locations' in file 'tribuit.xlsx':
# Empty DataFrame
# Columns: [Location, Attrition, Your attrition, % of employees]
# Index: []
#
# 5 head row for 'Schools' in file 'tribuit.xlsx':
#                              Schools  Employees  1y growth  1y hires  \
# 0  Chalmers University of Technology          3        0.0         0
# 1                University of Borås          1        0.0         0
# 2                Halmstad University          1        0.0         0
# 3           University of Gothenburg          1        0.0         0
# 4                       IT-Högskolan          1        NaN         1
#
#    % of employees    Your %
# 0           0.375  0.307209
# 1           0.125  0.017804
# 2           0.125  0.021993
# 3           0.125  0.051667
# 4           0.125  0.003142
#
# 5 head row for 'Degrees' in file 'tribuit.xlsx':
#                           Unnamed: 0  Tribuit Systems AB  Industry  \
# 0                    Master's Degree                   1  0.608070
# 1  Master of Business Administration                   0  0.066558
# 2                 Associate's Degree                   0  0.005025
# 3                  Bachelor's Degree                   0  0.256107
# 4               Doctor of Philosophy                   0  0.064239
#
#    Your company
# 0      0.614817
# 1      0.060962
# 2      0.003827
# 3      0.262985
# 4      0.057408
#
# 5 head row for 'Fields of Study' in file 'tribuit.xlsx':
#                           Fields of study  Employees  1y growth  1y hires  \
# 0  Electrical and Electronics Engineering          4        0.0         0
# 1                  Information Technology          2        1.0         1
# 2                             Informatics          2        0.0         0
# 3             Information Science/Studies          1        NaN         1
# 4                        Computer Science          1        0.0         0
#
#    % of employees    Your %
# 0           0.500  0.100890
# 1           0.250  0.043638
# 2           0.250  0.008029
# 3           0.125  0.006807
# 4           0.125  0.084133
#
# 5 head row for 'Overview' in file 'Vinngroup.xlsx':
#                          se-cr-vinngr-actrify-231114 Unnamed: 1 Unnamed: 2  \
# 0                                     Company Report        NaN        NaN
# 1                             Created on: 11/15/2023        NaN        NaN
# 2                              Created by Megan Reif        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4  For internal distribution only. All use subjec...        NaN        NaN
#
#   se-cr-vinngr-brimondo-231114 se-cr-vinngr-eclipse-231114  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
#
#   se-cr-vinngr-eyevinn-231114 se-cr-vinngr-goovinn-231114  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   se-cr-vinngr-hubbau-231114 se-cr-vinngr-humblebee-231114  \
# 0                        NaN                           NaN
# 1                        NaN                           NaN
# 2                        NaN                           NaN
# 3                        NaN                           NaN
# 4                        NaN                           NaN
#
#   se-cr-vinngr-pollen-231114 se-cr-vinngr-provinn-231114  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#   se-cr-vinngr-qinq-231114 se-cr-vinngr-redigo-231114  \
# 0                      NaN                        NaN
# 1                      NaN                        NaN
# 2                      NaN                        NaN
# 3                      NaN                        NaN
# 4                      NaN                        NaN
#
#   se-cr-vinngr-vinnter-231114 se-cr-vinngr-xvii-231114  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
#
#   se-cr-vinngr-yalta-231114 se-cr-vinngr-yovinn-231114 se-cr-vinngrAB-231114
# 0                       NaN                        NaN                   NaN
# 1                       NaN                        NaN                   NaN
# 2                       NaN                        NaN                   NaN
# 3                       NaN                        NaN                   NaN
# 4                       NaN                        NaN                   NaN
#
# 5 head row for 'Locations' in file 'Vinngroup.xlsx':
#                                 Location  Employees  1y hires  Job posts  \
# 0  Borås, Vastra Gotaland County, Sweden          2         1          0
# 1     Falkenberg, Halland County, Sweden          1         0          0
# 2   Greater Gothenburg Metropolitan Area        120        36          1
# 3        Greater Malmö Metropolitan Area          9         4          0
# 4    Greater Stockholm Metropolitan Area         37         9          0
#
#    N Last Year Employee    Your %  1 Year Growth  % of employees
# 0                   1.0  0.005059       1.000000        0.011364
# 1                   1.0  0.000349       0.000000        0.005682
# 2                  93.0  0.837579       0.290323        0.681818
# 3                   6.0  0.032100       0.500000        0.051136
# 4                  29.0  0.053210       0.275862        0.210227
#
# 5 head row for 'Company Movements' in file 'Vinngroup.xlsx':
#          Company  Departures  Hires  Net change  Ratio
# 0  Academic Work           0      1           1      1
# 1  Agile Content           0      1           1      1
# 2          Aptiv           0      1           1      1
# 3       AstaZero           0      1           1      1
# 4    AstraZeneca           0      1           1      1
#
# 5 head row for 'Location Movements' in file 'Vinngroup.xlsx':
#                                 Location  Departures  Hires  Net change  \
# 0  Borås, Vastra Gotaland County, Sweden           0      1           1
# 1   Greater Gothenburg Metropolitan Area           6     36          30
# 2        Greater Malmö Metropolitan Area           1      4           3
# 3    Greater Stockholm Metropolitan Area           2      9           7
# 4           Mora, Dalarna County, Sweden           1      0          -1
#
#       Ratio
# 0  1.000000
# 1  0.166667
# 2  0.250000
# 3  0.222222
# 4 -1.000000
#
# 5 head row for 'Industry Movements' in file 'Vinngroup.xlsx':
#                       Industry  Departures  Hires  Net change  Ratio
# 0                   Automotive           1      8           7  0.125
# 1                      Banking           0      2           2  2.000
# 2                Biotechnology           0      1           1  1.000
# 3  Computer & Network Security           0      1           1  1.000
# 4            Computer Software           1      2           1  0.500
#
# 5 head row for 'Titles' in file 'Vinngroup.xlsx':
#                        Titles  Employees  1y hires  Job posts  \
# 0  Advanced Software Engineer          1         1          0
# 1                     Advisor          1         0          0
# 2          Assistant Designer          3         0          0
# 3                Board Member          1         0          0
# 4            Business Analyst          1         1          0
#
#    N Last Year Employee    Your %  1 Year Growth  % of employees
# 0                   0.0  0.000000            NaN        0.005556
# 1                   1.0  0.000000            0.0        0.005556
# 2                   3.0  0.003664            0.0        0.016667
# 3                   1.0  0.001047            0.0        0.005556
# 4                   0.0  0.004187            NaN        0.005556
# 5 head row for 'Skills' in file 'Vinngroup.xlsx':
#                               Skills  Employees  1y hires  Job posts  \
# 0                          .NET Core          3         0          0
# 1                     .NET Framework         12         1          0
# 2  3D Computer Aided Design (3D CAD)          1         1          0
# 3                        3D Printing          4         1          0
# 4                   3D Visualization          3         1          0
#
#    N Last Year Employee    Your %  1 Year Growth  % of employees
# 0                   3.0  0.007327       0.000000        0.000955
# 1                  11.0  0.042742       0.090909        0.003818
# 2                   0.0  0.002094            NaN        0.000318
# 3                   3.0  0.010468       0.333333        0.001273
# 4                   2.0  0.004710       0.500000        0.000955
#
# 5 head row for 'Attrition by Functions' in file 'Vinngroup.xlsx':
# Empty DataFrame
# Columns: [Function, Attrition, Your attrition, % of employees, Departures, Average Employee, Attrition by Function]
# Index: []
#
# 5 head row for 'Attrition by Locations' in file 'Vinngroup.xlsx':
#                                Location  Attrition  Your attrition  \
# 0  Greater Gothenburg Metropolitan Area    0.11128        0.116072
# 1   Greater Stockholm Metropolitan Area    0.05000        0.150495
#
#    % of employees  Departures  Average Employee  Attrition by Locations
# 0        1.875000   10.518293        187.500000                0.056098
# 1        0.846154    4.230769         84.615386                0.050000
#
# 5 head row for 'Schools' in file 'Vinngroup.xlsx':
#                                        Schools  Employees  1y hires  \
# 0                American University of Beirut          1         1
# 1  Aristotle University of Thessaloniki (AUTH)          1         1
# 2               Berghs School of Communication          1         0
# 3             Blekinge Institute of Technology          4         2
# 4                 COMSATS University Islamabad          1         1
#
#    N Last Year Employee    Your %  1 Year Growth  % of employees
# 0                   0.0  0.000698            NaN        0.004219
# 1                   0.0  0.000872            NaN        0.004219
# 2                   1.0  0.000872            0.0        0.004219
# 3                   2.0  0.021458            1.0        0.016878
# 4                   0.0  0.000000            NaN        0.004219
#
# 5 head row for 'Degrees' in file 'Vinngroup.xlsx':
#                               Degree   Company  Industry  Your company
# 0                 Associate's Degree  0.000000  0.004027      0.003825
# 1                  Bachelor's Degree  0.309859  0.219985      0.262842
# 2               Doctor of Philosophy  0.085928  0.100428      0.057377
# 3  Master of Business Administration  0.031445  0.075258      0.060929
# 4                    Master's Degree  0.510269  0.600302      0.615027
#
# 5 head row for 'Fields of Study' in file 'Vinngroup.xlsx':
#                                      Fields of study  Employees  1y hires  \
# 0                 Accounting and Business/Management          1         0
# 1                    Accounting and Related Services          1         0
# 2  Aerospace, Aeronautical and Astronautical/Spac...          1         0
# 3  Animation, Interactive Technology, Video Graph...          1         0
# 4                                       Architecture          2         0
#
#    N Last Year Employee    Your %  1 Year Growth  % of employees
# 0                   1.0  0.000523            0.0        0.003115
# 1                   1.0  0.001396            0.0        0.003115
# 2                   1.0  0.005408            0.0        0.003115
# 3                   1.0  0.000000            0.0        0.003115
# 4                   2.0  0.003315            0.0        0.006231

# %% [markdown]
# #### Purpose:
#
# This step is vital for a preliminary examination of the data. It allows for a quick check of data formatting, column names, and the type of data contained in each sheet.
# Displaying the first few rows of each sheet helps in identifying any immediate data inconsistencies, missing values, or peculiarities that may require attention in the data cleaning or preprocessing stages.
# This overview is particularly beneficial when dealing with large datasets spread across multiple files and sheets, as it aids in quickly assessing the data's nature and structure without needing to manually open and inspect each file.

# %% [markdown]
# # Data Validation:

# %% [markdown]
# ### Checking for Missing Values in DataFrames
#
# This script section is designed to identify and report missing values in each sheet of every Excel file located in the `input_path`.

# %%
# Check for missing values in the DataFrame

for file_name in file_list:
    excel_file = pd.ExcelFile(os.path.join(input_path, file_name))
    sheets_list = excel_file.sheet_names

    for sheet_name in sheets_list:
        sheet_temp = excel_file.parse(sheet_name)
        
        missing_values = sheet_temp.isnull().sum()
        print(f"Missing values for sheet '{sheet_name}' in file '{file_name}': \n{missing_values}\n")
# Out:
# Missing values for sheet 'Overview' in file 'accenture.xlsx':
# se-cr-accenture-231113     8
# Unnamed: 1                20
# Unnamed: 2                24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'accenture.xlsx':
# Location          0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'accenture.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'accenture.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'accenture.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'accenture.xlsx':
# Titles             0
# Employees          0
# 1y growth         11
# 1y hires           0
# Job posts          0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'accenture.xlsx':
# Skills            0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'accenture.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'accenture.xlsx':
# Location          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'accenture.xlsx':
# Schools           0
# Employees         0
# 1y growth         5
# 1y hires          0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'accenture.xlsx':
# Unnamed: 0      0
# Accenture       0
# Industry        0
# Your company    0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'accenture.xlsx':
# Fields of study    0
# Employees          0
# 1y growth          0
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'afry.xlsx':
# se-cr-afry-231113     8
# Unnamed: 1           20
# Unnamed: 2           24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'afry.xlsx':
# Location          0
# Employees         0
# 1y growth         2
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'afry.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'afry.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'afry.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'afry.xlsx':
# Titles            0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'afry.xlsx':
# Skills            0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'afry.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'afry.xlsx':
# Location           0
# Attrition          0
# Your attrition    20
# % of employees     0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'afry.xlsx':
# Schools           0
# Employees         0
# 1y growth         0
# 1y hires          0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'afry.xlsx':
# Unnamed: 0      0
# AFRY            0
# Industry        0
# Your company    0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'afry.xlsx':
# Fields of study    0
# Employees          0
# 1y growth          0
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'akkodis.xlsx':
# se-cr-akkodis-231113     8
# Unnamed: 1              20
# Unnamed: 2              24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'akkodis.xlsx':
# Location          0
# Employees         0
# 1y growth         3
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'akkodis.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'akkodis.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'akkodis.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'akkodis.xlsx':
# Titles            0
# Employees         0
# 1y growth         6
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'akkodis.xlsx':
# Skills             0
# Employees          0
# 1y growth         18
# 1y hires           0
# Job posts          0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'akkodis.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'akkodis.xlsx':
# Location          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'akkodis.xlsx':
# Schools           0
# Employees         0
# 1y growth         6
# 1y hires          0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'akkodis.xlsx':
# Unnamed: 0      0
# Akkodis         0
# Industry        0
# Your company    0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'akkodis.xlsx':
# Fields of study     0
# Employees           0
# 1y growth          12
# 1y hires            0
# % of employees      0
# Your %              0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'Alten.xlsx':
# se-cr-alten-globalse-231113    34
# Unnamed: 1                     40
# Unnamed: 2                     48
# se-cr-alten-swe-231113         34
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'Alten.xlsx':
# Location                0
# Employees               0
# 1y hires                0
# Job posts               0
# N Last Year Employee    0
# Your %                  0
# 1 Year Growth           6
# % of employees          0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'Alten.xlsx':
# Company       0
# Departures    0
# Hires         0
# Net change    0
# Ratio         0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'Alten.xlsx':
# Location      0
# Departures    0
# Hires         0
# Net change    0
# Ratio         0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'Alten.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Net change    0
# Ratio         0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'Alten.xlsx':
# Titles                   0
# Employees                0
# 1y hires                 0
# Job posts                0
# N Last Year Employee     0
# Your %                   0
# 1 Year Growth           14
# % of employees           0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'Alten.xlsx':
# Skills                  0
# Employees               0
# 1y hires                0
# Job posts               0
# N Last Year Employee    0
# Your %                  0
# 1 Year Growth           0
# % of employees          0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'Alten.xlsx':
# Function                 0
# Attrition                0
# Your attrition           0
# % of employees           0
# Departures               0
# Average Employee         0
# Attrition by Function    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'Alten.xlsx':
# Location                  0
# Attrition                 0
# Your attrition            3
# % of employees            0
# Departures                0
# Average Employee          0
# Attrition by Locations    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'Alten.xlsx':
# Schools                  0
# Employees                0
# 1y hires                 0
# N Last Year Employee     0
# Your %                   0
# 1 Year Growth           20
# % of employees           0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'Alten.xlsx':
# Degree          0
# Company         0
# Industry        0
# Your company    0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'Alten.xlsx':
# Fields of study         0
# Employees               0
# 1y hires                0
# N Last Year Employee    0
# Your %                  0
# 1 Year Growth           8
# % of employees          0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'amaris.xlsx':
# se-cr-amaris-231113     8
# Unnamed: 1             20
# Unnamed: 2             24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'amaris.xlsx':
# Location          0
# Employees         0
# 1y growth         2
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'amaris.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'amaris.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'amaris.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'amaris.xlsx':
# Titles            0
# Employees         0
# 1y growth         9
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'amaris.xlsx':
# Skills            0
# Employees         0
# 1y growth         8
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'amaris.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'amaris.xlsx':
# Location          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'amaris.xlsx':
# Schools            0
# Employees          0
# 1y growth         18
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'amaris.xlsx':
# Unnamed: 0           0
# Amaris Consulting    0
# Industry             0
# Your company         0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'amaris.xlsx':
# Fields of study     0
# Employees           0
# 1y growth          11
# 1y hires            0
# % of employees      0
# Your %              0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'AVL.xlsx':
# se-cr-alvmtc-ab-231113       60
# Unnamed: 1                   60
# Unnamed: 2                   72
# se-cr-alvmtc-motor-231113    60
# se-cr-avl-231113             60
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'AVL.xlsx':
# Location                0
# Employees               0
# 1y hires                0
# Job posts               0
# N Last Year Employee    0
# Your %                  0
# 1 Year Growth           1
# % of employees          0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'AVL.xlsx':
# Company       0
# Departures    0
# Hires         0
# Net change    0
# Ratio         0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'AVL.xlsx':
# Location      0
# Departures    0
# Hires         0
# Net change    0
# Ratio         0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'AVL.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Net change    0
# Ratio         0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'AVL.xlsx':
# Titles                  0
# Employees               0
# 1y hires                0
# Job posts               0
# N Last Year Employee    0
# Your %                  0
# 1 Year Growth           5
# % of employees          0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'AVL.xlsx':
# Skills                   0
# Employees                0
# 1y hires                 0
# Job posts                0
# N Last Year Employee     0
# Your %                   0
# 1 Year Growth           32
# % of employees           0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'AVL.xlsx':
# Function                 0
# Attrition                0
# Your attrition           0
# % of employees           0
# Departures               0
# Average Employee         0
# Attrition by Function    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'AVL.xlsx':
# Location                  0
# Attrition                 0
# Your attrition            0
# % of employees            0
# Departures                0
# Average Employee          0
# Attrition by Locations    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'AVL.xlsx':
# Schools                  0
# Employees                0
# 1y hires                 0
# N Last Year Employee     0
# Your %                   0
# 1 Year Growth           12
# % of employees           0
# dtype: int64
# Missing values for sheet 'Degrees' in file 'AVL.xlsx':
# Degree          0
# Company         0
# Industry        0
# Your company    0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'AVL.xlsx':
# Fields of study          0
# Employees                0
# 1y hires                 0
# N Last Year Employee     0
# Your %                   0
# 1 Year Growth           12
# % of employees           0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'broccoli.xlsx':
# se-cr-broccoli-231113     8
# Unnamed: 1               20
# Unnamed: 2               24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'broccoli.xlsx':
# Location          0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'broccoli.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'broccoli.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'broccoli.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'broccoli.xlsx':
# Titles            0
# Employees         0
# 1y growth         2
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'broccoli.xlsx':
# Skills            0
# Employees         0
# 1y growth         1
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'broccoli.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'broccoli.xlsx':
# Location          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'broccoli.xlsx':
# Schools           0
# Employees         0
# 1y growth         0
# 1y hires          0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'broccoli.xlsx':
# Unnamed: 0      0
# Broccoli        0
# Industry        0
# Your company    0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'broccoli.xlsx':
# Fields of study    0
# Employees          0
# 1y growth          1
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'caevalue.xlsx':
# se-cr-caevalue-231113     8
# Unnamed: 1               20
# Unnamed: 2               24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'caevalue.xlsx':
# Location          0
# Employees         0
# 1y growth         1
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'caevalue.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'caevalue.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'caevalue.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'caevalue.xlsx':
# Titles            0
# Employees         0
# 1y growth         2
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'caevalue.xlsx':
# Skills            0
# Employees         0
# 1y growth         6
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'caevalue.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'caevalue.xlsx':
# Location          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'caevalue.xlsx':
# Schools           0
# Employees         0
# 1y growth         3
# 1y hires          0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'caevalue.xlsx':
# Unnamed: 0      0
# CAE Value AB    0
# Industry        0
# Your company    0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'caevalue.xlsx':
# Fields of study    0
# Employees          0
# 1y growth          1
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'cap-consult.xlsx':
# se-cr-cap-consult-231113     8
# Unnamed: 1                  20
# Unnamed: 2                  24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'cap-consult.xlsx':
# Location          0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'cap-consult.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'cap-consult.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'cap-consult.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'cap-consult.xlsx':
# Titles            0
# Employees         0
# 1y growth         1
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'cap-consult.xlsx':
# Skills            0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'cap-consult.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'cap-consult.xlsx':
# Location          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'cap-consult.xlsx':
# Schools           0
# Employees         0
# 1y growth         0
# 1y hires          0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'cap-consult.xlsx':
# Unnamed: 0      0
# Capgemini       0
# Industry        0
# Your company    0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'cap-consult.xlsx':
# Fields of study    0
# Employees          0
# 1y growth          0
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'cap-eng.xlsx':
# se-cr-cap-eng-231113     8
# Unnamed: 1              20
# Unnamed: 2              24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'cap-eng.xlsx':
# Location          0
# Employees         0
# 1y growth         4
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'cap-eng.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'cap-eng.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'cap-eng.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'cap-eng.xlsx':
# Titles             0
# Employees          0
# 1y growth         20
# 1y hires           0
# Job posts          0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'cap-eng.xlsx':
# Skills            0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'cap-eng.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'cap-eng.xlsx':
# Location          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'cap-eng.xlsx':
# Schools            0
# Employees          0
# 1y growth         23
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'cap-eng.xlsx':
# Unnamed: 0               0
# Capgemini Engineering    0
# Industry                 0
# Your company             0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'cap-eng.xlsx':
# Fields of study     0
# Employees           0
# 1y growth          15
# 1y hires            0
# % of employees      0
# Your %              0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'combitech.xlsx':
# se-cr-combitech-231113     8
# Unnamed: 1                20
# Unnamed: 2                24
# dtype: int64
# Missing values for sheet 'Locations' in file 'combitech.xlsx':
# Location          0
# Employees         0
# 1y growth         7
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'combitech.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'combitech.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'combitech.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'combitech.xlsx':
# Titles            0
# Employees         0
# 1y growth         2
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'combitech.xlsx':
# Skills            0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'combitech.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'combitech.xlsx':
# Location          0
# Attrition         0
# Your attrition    5
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'combitech.xlsx':
# Schools            0
# Employees          0
# 1y growth         15
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'combitech.xlsx':
# Unnamed: 0           0
# Combitech Sverige    0
# Industry             0
# Your company         0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'combitech.xlsx':
# Fields of study    0
# Employees          0
# 1y growth          0
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'condesign.xlsx':
# se-cr-condesign-231113     8
# Unnamed: 1                20
# Unnamed: 2                24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'condesign.xlsx':
# Location          0
# Employees         0
# 1y growth         1
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'condesign.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'condesign.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'condesign.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'condesign.xlsx':
# Titles            0
# Employees         0
# 1y growth         4
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'condesign.xlsx':
# Skills            0
# Employees         0
# 1y growth         3
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'condesign.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'condesign.xlsx':
# Location          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'condesign.xlsx':
# Schools           0
# Employees         0
# 1y growth         8
# 1y hires          0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'condesign.xlsx':
# Unnamed: 0      0
# Condesign AB    0
# Industry        0
# Your company    0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'condesign.xlsx':
# Fields of study     0
# Employees           0
# 1y growth          10
# 1y hires            0
# % of employees      0
# Your %              0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'consid.xlsx':
# se-cr-consid-231113     8
# Unnamed: 1             20
# Unnamed: 2             24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'consid.xlsx':
# Location           0
# Employees          0
# 1y growth         17
# 1y hires           0
# Job posts          0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'consid.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'consid.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'consid.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'consid.xlsx':
# Titles             0
# Employees          0
# 1y growth         12
# 1y hires           0
# Job posts          0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'consid.xlsx':
# Skills            0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'consid.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'consid.xlsx':
# Location          0
# Attrition         0
# Your attrition    8
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'consid.xlsx':
# Schools            0
# Employees          0
# 1y growth         26
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'consid.xlsx':
# Unnamed: 0      0
# Consid          0
# Industry        0
# Your company    0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'consid.xlsx':
# Fields of study    0
# Employees          0
# 1y growth          8
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'devport.xlsx':
# se-cr-devport-231113     8
# Unnamed: 1              20
# Unnamed: 2              24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'devport.xlsx':
# Location          0
# Employees         0
# 1y growth         6
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'devport.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'devport.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'devport.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'devport.xlsx':
# Titles             0
# Employees          0
# 1y growth         14
# 1y hires           0
# Job posts          0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'devport.xlsx':
# Skills            0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'devport.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'devport.xlsx':
# Location          0
# Attrition         0
# Your attrition    1
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'devport.xlsx':
# Schools            0
# Employees          0
# 1y growth         30
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'devport.xlsx':
# Unnamed: 0      0
# DevPort AB      0
# Industry        0
# Your company    0
# dtype: int64
# Missing values for sheet 'Fields of Study' in file 'devport.xlsx':
# Fields of study     0
# Employees           0
# 1y growth          15
# 1y hires            0
# % of employees      0
# Your %              0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'diadrom.xlsx':
# se-cr-diadrom-231113     8
# Unnamed: 1              20
# Unnamed: 2              24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'diadrom.xlsx':
# Location          0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'diadrom.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'diadrom.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'diadrom.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'diadrom.xlsx':
# Titles            0
# Employees         0
# 1y growth         2
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'diadrom.xlsx':
# Skills            0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'diadrom.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'diadrom.xlsx':
# Location          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'diadrom.xlsx':
# Schools           0
# Employees         0
# 1y growth         5
# 1y hires          0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'diadrom.xlsx':
# Unnamed: 0      0
# Diadrom         0
# Industry        0
# Your company    0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'diadrom.xlsx':
# Fields of study    0
# Employees          0
# 1y growth          3
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'edag.xlsx':
# se-cr-edag-engsw-231113     8
# Unnamed: 1                 20
# Unnamed: 2                 24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'edag.xlsx':
# Location          0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'edag.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'edag.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'edag.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'edag.xlsx':
# Titles            0
# Employees         0
# 1y growth         7
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'edag.xlsx':
# Skills            0
# Employees         0
# 1y growth         2
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'edag.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'edag.xlsx':
# Location          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'edag.xlsx':
# Schools            0
# Employees          0
# 1y growth         10
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'edag.xlsx':
# Unnamed: 0      0
# EDAG Group      0
# Industry        0
# Your company    0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'edag.xlsx':
# Fields of study    0
# Employees          0
# 1y growth          6
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'epam.xlsx':
# se-cr-epam-231113     8
# Unnamed: 1           20
# Unnamed: 2           24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'epam.xlsx':
# Location          0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'epam.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'epam.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'epam.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'epam.xlsx':
# Titles            0
# Employees         0
# 1y growth         1
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'epam.xlsx':
# Skills            0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'epam.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'epam.xlsx':
# Location          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'epam.xlsx':
# Schools           0
# Employees         0
# 1y growth         0
# 1y hires          0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'epam.xlsx':
# Unnamed: 0      0
# EPAM Systems    0
# Industry        0
# Your company    0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'epam.xlsx':
# Fields of study    0
# Employees          0
# 1y growth          0
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'etteplan.xlsx':
# se-cr-etteplan-231113     8
# Unnamed: 1               20
# Unnamed: 2               24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'etteplan.xlsx':
# Location          0
# Employees         0
# 1y growth         8
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'etteplan.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'etteplan.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'etteplan.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'etteplan.xlsx':
# Titles            0
# Employees         0
# 1y growth         8
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'etteplan.xlsx':
# Skills            0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'etteplan.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'etteplan.xlsx':
# Location          0
# Attrition         0
# Your attrition    4
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'etteplan.xlsx':
# Schools            0
# Employees          0
# 1y growth         18
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'etteplan.xlsx':
# Unnamed: 0      0
# Etteplan        0
# Industry        0
# Your company    0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'etteplan.xlsx':
# Fields of study    0
# Employees          0
# 1y growth          3
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'evidente.xlsx':
# se-cr-evidente-231113     8
# Unnamed: 1               20
# Unnamed: 2               24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'evidente.xlsx':
# Location          0
# Employees         0
# 1y growth         1
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'evidente.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'evidente.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'evidente.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'evidente.xlsx':
# Titles            0
# Employees         0
# 1y growth         3
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'evidente.xlsx':
# Skills            0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'evidente.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'evidente.xlsx':
# Location          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'evidente.xlsx':
# Schools           0
# Employees         0
# 1y growth         6
# 1y hires          0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'evidente.xlsx':
# Unnamed: 0      0
# Evidente        0
# Industry        0
# Your company    0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'evidente.xlsx':
# Fields of study    0
# Employees          0
# 1y growth          4
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
# Missing values for sheet 'Overview' in file 'expleo.xlsx':
# se-cr-expleo-231113     8
# Unnamed: 1             20
# Unnamed: 2             24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'expleo.xlsx':
# Location          0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'expleo.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'expleo.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'expleo.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'expleo.xlsx':
# Titles            0
# Employees         0
# 1y growth         7
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'expleo.xlsx':
# Skills            0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'expleo.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'expleo.xlsx':
# Location          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'expleo.xlsx':
# Schools            0
# Employees          0
# 1y growth         13
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'expleo.xlsx':
# Unnamed: 0      0
# Expleo Group    0
# Industry        0
# Your company    0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'expleo.xlsx':
# Fields of study    0
# Employees          0
# 1y growth          2
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'FEV.xlsx':
# se-cr-fev-europe-231113    34
# Unnamed: 1                 40
# Unnamed: 2                 48
# se-cr-fev-group-231113     34
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'FEV.xlsx':
# Location                0
# Employees               0
# 1y hires                0
# Job posts               0
# N Last Year Employee    0
# Your %                  0
# 1 Year Growth           0
# % of employees          0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'FEV.xlsx':
# Company       0
# Departures    0
# Hires         0
# Net change    0
# Ratio         0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'FEV.xlsx':
# Location      0
# Departures    0
# Hires         0
# Net change    0
# Ratio         0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'FEV.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Net change    0
# Ratio         0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'FEV.xlsx':
# Titles                  0
# Employees               0
# 1y hires                0
# Job posts               0
# N Last Year Employee    0
# Your %                  0
# 1 Year Growth           1
# % of employees          0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'FEV.xlsx':
# Skills                   0
# Employees                0
# 1y hires                 0
# Job posts                0
# N Last Year Employee     0
# Your %                   0
# 1 Year Growth           19
# % of employees           0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'FEV.xlsx':
# Function                 0
# Attrition                0
# Your attrition           0
# % of employees           0
# Departures               0
# Average Employee         0
# Attrition by Function    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'FEV.xlsx':
# Location                  0
# Attrition                 0
# Your attrition            0
# % of employees            0
# Departures                0
# Average Employee          0
# Attrition by Locations    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'FEV.xlsx':
# Schools                 0
# Employees               0
# 1y hires                0
# N Last Year Employee    0
# Your %                  0
# 1 Year Growth           0
# % of employees          0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'FEV.xlsx':
# Degree          0
# Company         0
# Industry        0
# Your company    0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'FEV.xlsx':
# Fields of study         0
# Employees               0
# 1y hires                0
# N Last Year Employee    0
# Your %                  0
# 1 Year Growth           5
# % of employees          0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'globallogic.xlsx':
# se-cr-globallogic-231113     8
# Unnamed: 1                  20
# Unnamed: 2                  24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'globallogic.xlsx':
# Location          0
# Employees         0
# ...
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'tata-consult.xlsx':
# Titles            0
# Employees         0
# 1y growth         2
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'tata-consult.xlsx':
# Skills            0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'tata-consult.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'tata-consult.xlsx':
# Location          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'tata-consult.xlsx':
# Schools           0
# Employees         0
# 1y growth         0
# 1y hires          0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'tata-consult.xlsx':
# Unnamed: 0                   0
# Tata Consultancy Services    0
# Industry                     0
# Your company                 0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'tata-consult.xlsx':
# Fields of study    0
# Employees          0
# 1y growth          1
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
# Missing values for sheet 'Overview' in file 'tata-tech.xlsx':
# se-cr-tata-tech-231113     8
# Unnamed: 1                20
# Unnamed: 2                24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'tata-tech.xlsx':
# Location          0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'tata-tech.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'tata-tech.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'tata-tech.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'tata-tech.xlsx':
# Titles            0
# Employees         0
# 1y growth         8
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'tata-tech.xlsx':
# Skills            0
# Employees         0
# 1y growth         3
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'tata-tech.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'tata-tech.xlsx':
# Location          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'tata-tech.xlsx':
# Schools            0
# Employees          0
# 1y growth         10
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'tata-tech.xlsx':
# Unnamed: 0           0
# Tata Technologies    0
# Industry             0
# Your company         0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'tata-tech.xlsx':
# Fields of study    0
# Employees          0
# 1y growth          1
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'techmahindra.xlsx':
# se-cr-techmahindra-231113     8
# Unnamed: 1                   20
# Unnamed: 2                   24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'techmahindra.xlsx':
# Location          0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'techmahindra.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'techmahindra.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'techmahindra.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'techmahindra.xlsx':
# Titles            0
# Employees         0
# 1y growth         2
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'techmahindra.xlsx':
# Skills            0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'techmahindra.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'techmahindra.xlsx':
# Location          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'techmahindra.xlsx':
# Schools           0
# Employees         0
# 1y growth         0
# 1y hires          0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'techmahindra.xlsx':
# Unnamed: 0       0
# Tech Mahindra    0
# Industry         0
# Your company     0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'techmahindra.xlsx':
# Fields of study    0
# Employees          0
# 1y growth          0
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'tieto.xlsx':
# se-cr-tieto-231113     8
# Unnamed: 1            20
# Unnamed: 2            24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'tieto.xlsx':
# Location          0
# Employees         0
# 1y growth         5
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'tieto.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'tieto.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'tieto.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'tieto.xlsx':
# Titles            0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'tieto.xlsx':
# Skills            0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'tieto.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'tieto.xlsx':
# Location          0
# Attrition         0
# Your attrition    6
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'tieto.xlsx':
# Schools           0
# Employees         0
# 1y growth         5
# 1y hires          0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'tieto.xlsx':
# Unnamed: 0      0
# Tieto           0
# Industry        0
# Your company    0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'tieto.xlsx':
# Fields of study    0
# Employees          0
# 1y growth          0
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'togethertech.xlsx':
# se-cr-togethertech-231113     8
# Unnamed: 1                   20
# Unnamed: 2                   24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'togethertech.xlsx':
# Location          0
# Employees         0
# 1y growth         1
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'togethertech.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'togethertech.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'togethertech.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'togethertech.xlsx':
# Titles            0
# Employees         0
# 1y growth         6
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'togethertech.xlsx':
# Skills            0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'togethertech.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'togethertech.xlsx':
# Location          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'togethertech.xlsx':
# Schools            0
# Employees          0
# 1y growth         17
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'togethertech.xlsx':
# Unnamed: 0       0
# Together Tech    0
# Industry         0
# Your company     0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'togethertech.xlsx':
# Fields of study    0
# Employees          0
# 1y growth          7
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Overview' in file 'tribuit.xlsx':
# se-cr-tribuit-231113     8
# Unnamed: 1              20
# Unnamed: 2              24
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'tribuit.xlsx':
# Location          0
# Employees         0
# 1y growth         0
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'tribuit.xlsx':
# Company       0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'tribuit.xlsx':
# Location      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'tribuit.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Ratio         0
# Net change    0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'tribuit.xlsx':
# Titles            0
# Employees         0
# 1y growth         1
# 1y hires          0
# Job posts         0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'tribuit.xlsx':
# Skills             0
# Employees          0
# 1y growth         18
# 1y hires           0
# Job posts          0
# % of employees     0
# Your %             0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'tribuit.xlsx':
# Function          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'tribuit.xlsx':
# Location          0
# Attrition         0
# Your attrition    0
# % of employees    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'tribuit.xlsx':
# Schools           0
# Employees         0
# 1y growth         3
# 1y hires          0
# % of employees    0
# Your %            0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'tribuit.xlsx':
# Unnamed: 0            0
# Tribuit Systems AB    0
# Industry              0
# Your company          0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'tribuit.xlsx':
# Fields of study    0
# Employees          0
# 1y growth          5
# 1y hires           0
# % of employees     0
# Your %             0
# dtype: int64
# Missing values for sheet 'Overview' in file 'Vinngroup.xlsx':
# se-cr-vinngr-actrify-231114      398
# Unnamed: 1                       320
# Unnamed: 2                       384
# se-cr-vinngr-brimondo-231114     398
# se-cr-vinngr-eclipse-231114      398
# se-cr-vinngr-eyevinn-231114      398
# se-cr-vinngr-goovinn-231114      398
# se-cr-vinngr-hubbau-231114       398
# se-cr-vinngr-humblebee-231114    398
# se-cr-vinngr-pollen-231114       398
# se-cr-vinngr-provinn-231114      398
# se-cr-vinngr-qinq-231114         398
# se-cr-vinngr-redigo-231114       398
# se-cr-vinngr-vinnter-231114      398
# se-cr-vinngr-xvii-231114         398
# se-cr-vinngr-yalta-231114        398
# se-cr-vinngr-yovinn-231114       398
# se-cr-vinngrAB-231114            398
# dtype: int64
#
# Missing values for sheet 'Locations' in file 'Vinngroup.xlsx':
# Location                0
# Employees               0
# 1y hires                0
# Job posts               0
# N Last Year Employee    0
# Your %                  0
# 1 Year Growth           2
# % of employees          0
# dtype: int64
#
# Missing values for sheet 'Company Movements' in file 'Vinngroup.xlsx':
# Company       0
# Departures    0
# Hires         0
# Net change    0
# Ratio         0
# dtype: int64
#
# Missing values for sheet 'Location Movements' in file 'Vinngroup.xlsx':
# Location      0
# Departures    0
# Hires         0
# Net change    0
# Ratio         0
# dtype: int64
#
# Missing values for sheet 'Industry Movements' in file 'Vinngroup.xlsx':
# Industry      0
# Departures    0
# Hires         0
# Net change    0
# Ratio         0
# dtype: int64
#
# Missing values for sheet 'Titles' in file 'Vinngroup.xlsx':
# Titles                   0
# Employees                0
# 1y hires                 0
# Job posts                0
# N Last Year Employee     0
# Your %                   0
# 1 Year Growth           20
# % of employees           0
# dtype: int64
#
# Missing values for sheet 'Skills' in file 'Vinngroup.xlsx':
# Skills                    0
# Employees                 0
# 1y hires                  0
# Job posts                 0
# N Last Year Employee      0
# Your %                    0
# 1 Year Growth           213
# % of employees            0
# dtype: int64
#
# Missing values for sheet 'Attrition by Functions' in file 'Vinngroup.xlsx':
# Function                 0
# Attrition                0
# Your attrition           0
# % of employees           0
# Departures               0
# Average Employee         0
# Attrition by Function    0
# dtype: int64
#
# Missing values for sheet 'Attrition by Locations' in file 'Vinngroup.xlsx':
# Location                  0
# Attrition                 0
# Your attrition            0
# % of employees            0
# Departures                0
# Average Employee          0
# Attrition by Locations    0
# dtype: int64
#
# Missing values for sheet 'Schools' in file 'Vinngroup.xlsx':
# Schools                  0
# Employees                0
# 1y hires                 0
# N Last Year Employee     0
# Your %                   0
# 1 Year Growth           22
# % of employees           0
# dtype: int64
#
# Missing values for sheet 'Degrees' in file 'Vinngroup.xlsx':
# Degree          0
# Company         0
# Industry        0
# Your company    0
# dtype: int64
#
# Missing values for sheet 'Fields of Study' in file 'Vinngroup.xlsx':
# Fields of study          0
# Employees                0
# 1y hires                 0
# N Last Year Employee     0
# Your %                   0
# 1 Year Growth           14
# % of employees           0
# dtype: int64

# %% [markdown]
# # Aggregating and Processing Data

# %% [markdown]
# ### - Consolidating and Enhancing Data from Multiple Excel Sheets

# %%
# Get the sheet names from the first file in the list
initial_sheets_list = pd.ExcelFile(input_path + file_list[0]).sheet_names

final_result = dict()

for sheet_slected in initial_sheets_list:
    final_sheet = pd.DataFrame()
    
    for file_name in file_list:
        temp_sheet = pd.read_excel(input_path + file_name, sheet_slected, index_col=False)
        
        if sheet_slected == 'Degrees':
            temp_sheet = temp_sheet.rename(columns={temp_sheet.columns[0]: 'Degree', temp_sheet.columns[1]: 'Company'})
            
        

        if (sheet_slected == 'Company Movements'):
            temp_sheet['Consultant Company'] = temp_sheet['Company'].str.lower().str.contains("|".join(consultant_filter_list)).apply(lambda x: 1 if x else 0)
            temp_sheet['Automotive Company'] = temp_sheet['Company'].str.lower().str.contains("|".join(automative_company_filter_list)).apply(lambda x: 1 if x else 0)
            
            temp_sheet['company_lower'] = temp_sheet['Company'].str.lower()
            
                        
            
        temp_sheet = temp_sheet.assign(Company_Name=file_name.split(".")[0])
        final_sheet = pd.concat([final_sheet, temp_sheet], ignore_index=True)
         
        
    final_result[sheet_slected] = final_sheet
# Out:
# C:\Users\zkarimib@volvocars.com\AppData\Local\Temp\ipykernel_2988\1579534233.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_sheet = pd.concat([final_sheet, temp_sheet], ignore_index=True)
# C:\Users\zkarimib@volvocars.com\AppData\Local\Temp\ipykernel_2988\1579534233.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_sheet = pd.concat([final_sheet, temp_sheet], ignore_index=True)
# C:\Users\zkarimib@volvocars.com\AppData\Local\Temp\ipykernel_2988\1579534233.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_sheet = pd.concat([final_sheet, temp_sheet], ignore_index=True)
# C:\Users\zkarimib@volvocars.com\AppData\Local\Temp\ipykernel_2988\1579534233.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_sheet = pd.concat([final_sheet, temp_sheet], ignore_index=True)
# C:\Users\zkarimib@volvocars.com\AppData\Local\Temp\ipykernel_2988\1579534233.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_sheet = pd.concat([final_sheet, temp_sheet], ignore_index=True)
# C:\Users\zkarimib@volvocars.com\AppData\Local\Temp\ipykernel_2988\1579534233.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_sheet = pd.concat([final_sheet, temp_sheet], ignore_index=True)
# C:\Users\zkarimib@volvocars.com\AppData\Local\Temp\ipykernel_2988\1579534233.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_sheet = pd.concat([final_sheet, temp_sheet], ignore_index=True)
# C:\Users\zkarimib@volvocars.com\AppData\Local\Temp\ipykernel_2988\1579534233.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_sheet = pd.concat([final_sheet, temp_sheet], ignore_index=True)
# C:\Users\zkarimib@volvocars.com\AppData\Local\Temp\ipykernel_2988\1579534233.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_sheet = pd.concat([final_sheet, temp_sheet], ignore_index=True)
# C:\Users\zkarimib@volvocars.com\AppData\Local\Temp\ipykernel_2988\1579534233.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_sheet = pd.concat([final_sheet, temp_sheet], ignore_index=True)
# C:\Users\zkarimib@volvocars.com\AppData\Local\Temp\ipykernel_2988\1579534233.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_sheet = pd.concat([final_sheet, temp_sheet], ignore_index=True)
# C:\Users\zkarimib@volvocars.com\AppData\Local\Temp\ipykernel_2988\1579534233.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_sheet = pd.concat([final_sheet, temp_sheet], ignore_index=True)
# C:\Users\zkarimib@volvocars.com\AppData\Local\Temp\ipykernel_2988\1579534233.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_sheet = pd.concat([final_sheet, temp_sheet], ignore_index=True)
# C:\Users\zkarimib@volvocars.com\AppData\Local\Temp\ipykernel_2988\1579534233.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_sheet = pd.concat([final_sheet, temp_sheet], ignore_index=True)

# %% [markdown]
# ### Overview of Operations
#
# #### Initial Sheet Name Extraction
# - Retrieves the list of sheet names from the first file in the list to set a standard for processing.
#
# #### Dataframe Initialization
# - Initializes a dictionary to store the final aggregated data from all sheets.
#
# #### Sheet-Wise Data Processing
# - Iterates through each selected sheet, reading and processing data from all files.
# - Applies specific transformations depending on the sheet type (e.g., renaming columns in 'Degrees', categorizing companies in 'Company Movements').
#
# #### Company Categorization and Ranking
# - Includes logic to categorize companies as 'Consultant' or 'Automotive', and to rank them based on predefined criteria.
#
# #### Data Aggregation
# - Combines data from individual files into a comprehensive DataFrame for each sheet.
#
# ### Purpose
#
# - This script segment is tailored for handling diverse datasets spread across multiple Excel files, ensuring data integrity and consistency.
# - The transformations and categorizations applied are specific to the project's focus on evaluating consulting suppliers in Sweden, taking into account various factors like degrees, company movements, and rankings.
# - The final result is an aggregated, enriched dataset ready for further analysis or visualization, facilitating in-depth insights into supplier quality.

# %% [markdown]
# ### - Modification of Location Data in 'Locations' and 'Location Movements' Sheets

# %%
#modify Location column 

final_result['Locations']['Location'] = final_result['Locations']['Location'].replace('Area', '', regex=True).replace('Greater', '', regex=True).replace('Metropolitan', '', regex=True).replace('City', '', regex=True).replace('County', '', regex=True)
final_result['Location Movements']['Location'] = final_result['Location Movements']['Location'].replace('Area', '', regex=True).replace('Greater', '', regex=True).replace('Metropolitan', '', regex=True).replace('City', '', regex=True).replace('County', '', regex=True)
final_result['Attrition by Locations']['Location'] = final_result['Attrition by Locations']['Location'].replace('Area', '', regex=True).replace('Greater', '', regex=True).replace('Metropolitan', '', regex=True).replace('City', '', regex=True).replace('County', '', regex=True)

# %% [markdown]
# #### Key Actions in Location Data Modification
#
# **Regex-Based Replacement**
# - The script employs regular expressions to remove specific words from the 'Location' column in both sheets.
#
# **Target Words for Removal**
# - Words like 'Area', 'Greater', 'Metropolitan', 'City', and 'County' are targeted for removal to streamline the location data.
#
# **Application to Multiple Sheets**
# - Similar transformations are applied to both the 'Locations' and 'Location Movements' sheets.

# %%
final_result['Company Movements']['Company']=final_result['Company Movements']['Company'].str.lower()

# %% [markdown]
# ## -Splitting and Reformatting 'Location' Data in DataFrames

# %%
# Split 'Location' column and handle different cases
split_locations = final_result['Locations']['Location'].str.split(",", n=2, expand=True)

# Assign the result to new columns
final_result['Locations'][['City', 'County', 'Country']] = split_locations

# Fill the entire 'Country' column with 'Sweden'
final_result['Locations']['Country'] = 'Sweden'

# %%
# Split 'Location' column and handle different cases
split_locations = final_result['Location Movements']['Location'].str.split(",", n=2, expand=True)

# Assign the result to new columns
final_result['Location Movements'][['City', 'County', 'Country']] = split_locations

# Fill the entire 'Country' column with 'Sweden'
final_result['Location Movements']['Country'] = 'Sweden'

# %%
# Split 'Location' column and handle different cases
split_locations = final_result['Attrition by Locations']['Location'].str.split(",", n=2, expand=True)

# Assign the result to new columns
final_result['Attrition by Locations'][['City', 'County', 'Country']] = split_locations

# Fill the entire 'Country' column with 'Sweden'
final_result['Attrition by Locations']['Country'] = 'Sweden'

# %% [markdown]
# #### Detailed Breakdown of Location Data Processing
#
# **Splitting Location Data**
# - The 'Location' column in both 'Locations' and 'Location Movements' sheets is split into separate components based on commas, using the `str.split` method with `expand=True`.
# - The split is restricted to a maximum of two commas (three parts) to ensure consistency in the data format.
#
# **Creating New Columns**
# - The results of the split are then assigned to new columns: 'City', 'County', and 'Country'.
# - This reformatting allows for a more structured and detailed representation of location data.
#
# **Standardizing Country Data**
# - In the 'Locations' sheet, the 'Country' column is uniformly filled with 'Sweden', standardizing this aspect of the dataset.

# %%
# Replace non-standard commas or semicolons (or any other unexpected delimiter) with a standard comma
final_result['Attrition by Locations']['Location'] = final_result['Attrition by Locations']['Location'].str.replace(r'[;]', ',', regex=True)

# Then try splitting again
split_locations = final_result['Attrition by Locations']['Location'].str.split(r'\s*,\s*', expand=True)

# %%
sheets_to_process = ['Attrition by Locations']


for sheet_name in sheets_to_process:
    if sheet_name in final_result:
        
        # Fill missing values in the 'Attrition by Location' column with values from 'Attrition' column
        final_result[sheet_name]['Attrition by Locations'] = final_result[sheet_name]['Attrition by Locations'].fillna(final_result[sheet_name]['Attrition'])
        
        # Fill missing values in the 'Average Employee' column with values from % of employees'*100' 
        final_result[sheet_name]['Average Employee'] = final_result[sheet_name]['Average Employee'].fillna(final_result[sheet_name]['% of employees']*100)
        
        # Fill missing values in the ''Departures' column with values from 'Attrition'*'Average Employee' 
        final_result[sheet_name]['Departures'] = final_result[sheet_name]['Departures'].fillna(final_result[sheet_name]['Attrition']*final_result[sheet_name]['Average Employee'])
    else:
        print(f"{sheet_name} not found in final_result dictionary")


print(final_result['Attrition by Locations'])
# Out:
#                     Location  Attrition  Your attrition  % of employees  \
# 0                Stockholm     0.173913        0.150495        0.745098
# 1               Gothenburg     0.281690        0.115924        0.111111
# 2                    Malmö     0.162162        0.132964        0.065359
# 3                Stockholm     0.200131        0.150495        0.257606
# 4               Gothenburg     0.179104        0.115924        0.225490
# ..                       ...        ...             ...             ...
# 147                Uppsala     0.098039             NaN        0.042345
# 148  Kalmar, Kalmar , Sweden   0.098765             NaN        0.034202
# 149             Gothenburg     0.131737        0.115924        0.688525
# 150             Gothenburg     0.111280        0.116072        1.875000
# 151              Stockholm     0.050000        0.150495        0.846154
#
#      Company_Name  Departures  Average Employee  Attrition by Locations  \
# 0       accenture   12.958227         74.509805                0.173913
# 1       accenture    3.129891         11.111111                0.281690
# 2       accenture    1.059883          6.535948                0.162162
# 3            afry    5.155499         25.760648                0.200131
# 4            afry    4.038630         22.549020                0.179104
# ..            ...         ...               ...                     ...
# 147         tieto    0.415150          4.234528                0.098039
# 148         tieto    0.337797          3.420195                0.098765
# 149  togethertech    9.070384         68.852460                0.131737
# 150     Vinngroup   10.518293        187.500000                0.056098
# 151     Vinngroup    4.230769         84.615386                0.050000
#
#               City    County Country
# 0      Stockholm        None  Sweden
# 1     Gothenburg        None  Sweden
# 2          Malmö        None  Sweden
# 3      Stockholm        None  Sweden
# 4     Gothenburg        None  Sweden
# ..             ...       ...     ...
# 147      Uppsala        None  Sweden
# 148         Kalmar   Kalmar   Sweden
# 149   Gothenburg        None  Sweden
# 150   Gothenburg        None  Sweden
# 151    Stockholm        None  Sweden
#
# [152 rows x 11 columns]

# %%
sheets_to_process = ['Attrition by Functions']


for sheet_name in sheets_to_process:
    if sheet_name in final_result:
        
        # Fill missing values in the '1 Year Growth' column with values from '1y growth' column
        final_result[sheet_name]['Attrition by Function'] = final_result[sheet_name]['Attrition by Function'].fillna(final_result[sheet_name]['Attrition'])
        
        # Fill missing values in the 'Average Employee' column with values from % of employees'*100' 
        final_result[sheet_name]['Average Employee'] = final_result[sheet_name]['Average Employee'].fillna(final_result[sheet_name]['% of employees']*100)
        
        # Fill missing values in the ''Departures' column with values from 'Attrition'*'Average Employee' 
        final_result[sheet_name]['Departures'] = final_result[sheet_name]['Departures'].fillna(final_result[sheet_name]['Attrition']*final_result[sheet_name]['Average Employee'])
    else:
        print(f"{sheet_name} not found in final_result dictionary")


print(final_result['Attrition by Functions'])
# Out:
#                          Function  Attrition  Your attrition  % of employees  \
# 0                     Engineering   0.210526        0.095893        0.209150
# 1          Information Technology   0.179104        0.137625        0.209150
# 2            Business Development   0.052174        0.145985        0.199346
# 3                      Consulting   0.285714        0.148148        0.068627
# 4                      Operations   0.114286        0.165121        0.058824
# ..                            ...        ...             ...             ...
# 132  Customer Success and Support   0.100000        0.125000        0.016287
# 133                      Research   0.125000        0.218905        0.011401
# 134        Information Technology   0.265306        0.137625        0.401639
# 135                   Engineering   0.194444        0.095893        0.286885
# 136                         Sales   0.117647        0.198020        0.147541
#
#      Company_Name  Departures  Average Employee  Attrition by Function
# 0       accenture    4.403165         20.915033               0.210526
# 1       accenture    3.745976         20.915033               0.179104
# 2       accenture    1.040068         19.934641               0.052174
# 3       accenture    1.960784          6.862745               0.285714
# 4       accenture    0.672269          5.882353               0.114286
# ..            ...         ...               ...                    ...
# 132         tieto    0.162866          1.628665               0.100000
# 133         tieto    0.142508          1.140065               0.125000
# 134  togethertech   10.655737         40.163934               0.265306
# 135  togethertech    5.578324         28.688523               0.194444
# 136  togethertech    1.735776         14.754099               0.117647
#
# [137 rows x 8 columns]

# %%
sheets_to_process = ['Locations', 'Titles', 'Skills', 'Schools', 'Fields of Study']


for sheet_name in sheets_to_process:
    if sheet_name in final_result:
        
        # Fill missing values in the '1 Year Growth' column with values from '1y growth' column
        final_result[sheet_name]['1 Year Growth'] = final_result[sheet_name]['1 Year Growth'].fillna(final_result[sheet_name]['1y growth'])
    else:
        print(f"{sheet_name} not found in final_result dictionary")

# Print the updated final_result dictionary
print(final_result)
# Out:
# {'Overview':                                  se-cr-accenture-231113      Unnamed: 1  \
# 0                                        Company Report             NaN
# 1                                Created on: 11/13/2023             NaN
# 2                                 Created by Megan Reif             NaN
# 3                                                   NaN             NaN
# 4     For internal distribution only. All use subjec...             NaN
# ...                                                 ...             ...
# 2023                                                NaN             NaN
# 2024                                                NaN             NaN
# 2025                                                NaN             NaN
# 2026                                                NaN            Type
# 2027                                                NaN  Months of data
#
#      Unnamed: 2 Company_Name se-cr-afry-231113 se-cr-akkodis-231113  \
# 0           NaN    accenture               NaN                  NaN
# 1           NaN    accenture               NaN                  NaN
# 2           NaN    accenture               NaN                  NaN
# 3           NaN    accenture               NaN                  NaN
# 4           NaN    accenture               NaN                  NaN
# ...         ...          ...               ...                  ...
# 2023        NaN    Vinngroup               NaN                  NaN
# 2024        NaN    Vinngroup               NaN                  NaN
# 2025        NaN    Vinngroup               NaN                  NaN
# 2026      Value    Vinngroup               NaN                  NaN
# 2027         12    Vinngroup               NaN                  NaN
#
#      se-cr-alten-globalse-231113 se-cr-alten-swe-231113 se-cr-amaris-231113  \
# 0                            NaN                    NaN                 NaN
# 1                            NaN                    NaN                 NaN
# 2                            NaN                    NaN                 NaN
# 3                            NaN                    NaN                 NaN
# 4                            NaN                    NaN                 NaN
# ...                          ...                    ...                 ...
# 2023                         NaN                    NaN                 NaN
# 2024                         NaN                    NaN                 NaN
# 2025                         NaN                    NaN                 NaN
# 2026                         NaN                    NaN                 NaN
# 2027                         NaN                    NaN                 NaN
#
#      se-cr-alvmtc-ab-231113  ... se-cr-vinngr-humblebee-231114  \
# 0                       NaN  ...                           NaN
# 1                       NaN  ...                           NaN
# 2                       NaN  ...                           NaN
# 3                       NaN  ...                           NaN
# 4                       NaN  ...                           NaN
# ...                     ...  ...                           ...
# 2023                    NaN  ...                           NaN
# 2024                    NaN  ...                           NaN
# 2025                    NaN  ...                           NaN
# 2026                    NaN  ...                           NaN
# 2027                    NaN  ...                           NaN
#
#      se-cr-vinngr-pollen-231114 se-cr-vinngr-provinn-231114  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ...                         ...                         ...
# 2023                        NaN                         NaN
# 2024                        NaN                         NaN
# 2025                        NaN                         NaN
# 2026                        NaN                         NaN
# 2027                        NaN                         NaN
#
#      se-cr-vinngr-qinq-231114 se-cr-vinngr-redigo-231114  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ...                       ...                        ...
# 2023                      NaN                        NaN
# 2024                      NaN                        NaN
# 2025                      NaN                        NaN
# 2026                      NaN                        NaN
# 2027                      NaN                        NaN
#
#      se-cr-vinngr-vinnter-231114 se-cr-vinngr-xvii-231114  \
# 0                            NaN                      NaN
# 1                            NaN                      NaN
# 2                            NaN                      NaN
# 3                            NaN                      NaN
# 4                            NaN                      NaN
# ...                          ...                      ...
# 2023                         NaN                      NaN
# 2024                         NaN                      NaN
# 2025                         NaN                      NaN
# 2026                         NaN                      NaN
# 2027                         NaN                      NaN
#
#      se-cr-vinngr-yalta-231114 se-cr-vinngr-yovinn-231114  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2023                       NaN                        NaN
# 2024                       NaN                        NaN
# 2025                       NaN                        NaN
# 2026                       NaN                        NaN
# 2027                       NaN                        NaN
#
#      se-cr-vinngrAB-231114
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 2023                   NaN
# 2024        Tab Parameters
# 2025                   NaN
# 2026                   Tab
# 2027     Company Movements
#
# [2028 rows x 81 columns], 'Locations':                                   Location  Employees  1y growth  1y hires  \
# 0                              Stockholm          228  -0.017241        38
# 1                             Gothenburg           34  -0.081081         6
# 2                                  Malmö           20   0.176471         5
# 3                 Täby, Stockholm , Sweden          8   0.000000         1
# 4                                Uppsala            5  -0.285714         2
# ..                                     ...        ...        ...       ...
# 889             Halmstad, Halland , Sweden          1        NaN         0
# 890    Kungshamn, Vastra Gotaland , Sweden          1        NaN         0
# 891  Trollhättan, Vastra Gotaland , Sweden          2        NaN         2
# 892    Uddevalla, Vastra Gotaland , Sweden          1        NaN         0
# 893   Vänersborg, Vastra Gotaland , Sweden          1        NaN         1
#
#      Job posts  % of employees    Your % Company_Name  N Last Year Employee  \
# 0            4        0.745098  0.053238    accenture                   NaN
# 1            0        0.111111  0.837493    accenture                   NaN
# 2            0        0.065359  0.032117    accenture                   NaN
# 3            0        0.026144  0.000698    accenture                   NaN
# 4            0        0.016340  0.002967    accenture                   NaN
# ..         ...             ...       ...          ...                   ...
# 889          0        0.005682  0.001221    Vinngroup                   1.0
# 890          0        0.005682  0.000174    Vinngroup                   1.0
# 891          0        0.011364  0.013782    Vinngroup                   0.0
# 892          0        0.005682  0.003664    Vinngroup                   1.0
# 893          0        0.005682  0.002094    Vinngroup                   0.0
#
#      1 Year Growth           City             County Country
# 0        -0.017241    Stockholm                 None  Sweden
# 1        -0.081081   Gothenburg                 None  Sweden
# 2         0.176471        Malmö                 None  Sweden
# 3         0.000000           Täby         Stockholm   Sweden
# 4        -0.285714      Uppsala                 None  Sweden
# ..             ...            ...                ...     ...
# 889       0.000000       Halmstad           Halland   Sweden
# 890       0.000000      Kungshamn   Vastra Gotaland   Sweden
# 891            NaN    Trollhättan   Vastra Gotaland   Sweden
# 892       0.000000      Uddevalla   Vastra Gotaland   Sweden
# 893            NaN     Vänersborg   Vastra Gotaland   Sweden
#
# [894 rows x 13 columns], 'Company Movements':                         Company Departures Hires  Ratio Net change  \
# 0                            ey          2     3    1.5          1
# 1                      netlight          3     0   -3.0         -3
# 2                    volvo cars          3     0   -3.0         -3
# 3     tata consultancy services          0     2    2.0          2
# 4              capgemini invent          1     1    1.0          0
# ...                         ...        ...   ...    ...        ...
# 2325                    teachiq          1     0   -1.0         -1
# 2326                 volvo cars          0     2    2.0          2
# 2327                volvo group          0     2    2.0          2
# 2328       volvo trucks sverige          0     1    1.0          1
# 2329                   zenseact          0     1    1.0          1
#
#       Consultant Company  Automotive Company              company_lower  \
# 0                      0                   0                         ey
# 1                      1                   0                   netlight
# 2                      0                   1                 volvo cars
# 3                      1                   0  tata consultancy services
# 4                      1                   0           capgemini invent
# ...                  ...                 ...                        ...
# 2325                   1                   0                    teachiq
# 2326                   0                   1                 volvo cars
# 2327                   0                   1                volvo group
# 2328                   0                   1       volvo trucks sverige
# 2329                   0                   1                   zenseact
#
#      Company_Name
# 0       accenture
# 1       accenture
# 2       accenture
# 3       accenture
# 4       accenture
# ...           ...
# 2325    Vinngroup
# 2326    Vinngroup
# 2327    Vinngroup
# 2328    Vinngroup
# 2329    Vinngroup
#
# [2330 rows x 9 columns], 'Location Movements':                                   Location  Departures  Hires     Ratio  \
# 0                              Stockholm            40     38 -1.052632
# 1                             Gothenburg            10      6 -1.666667
# 2                                  Malmö             3      5  1.666667
# 3                                Uppsala             4      2 -2.000000
# 4                Luleå, Norrbotten, Sweden           2      2  1.000000
# ..                                     ...         ...    ...       ...
# 641                                Malmö             1      4  0.250000
# 642                            Stockholm             2      9  0.222222
# 643                 Mora, Dalarna , Sweden           1      0 -1.000000
# 644  Trollhättan, Vastra Gotaland , Sweden           0      2  2.000000
# 645   Vänersborg, Vastra Gotaland , Sweden           0      1  1.000000
#
#      Net change Company_Name           City             County Country
# 0            -2    accenture    Stockholm                 None  Sweden
# 1            -4    accenture   Gothenburg                 None  Sweden
# 2             2    accenture        Malmö                 None  Sweden
# 3            -2    accenture      Uppsala                 None  Sweden
# 4             0    accenture          Luleå         Norrbotten  Sweden
# ..          ...          ...            ...                ...     ...
# 641           3    Vinngroup        Malmö                 None  Sweden
# 642           7    Vinngroup    Stockholm                 None  Sweden
# 643          -1    Vinngroup           Mora           Dalarna   Sweden
# 644           2    Vinngroup    Trollhättan   Vastra Gotaland   Sweden
# 645           1    Vinngroup     Vänersborg   Vastra Gotaland   Sweden
#
# [646 rows x 9 columns], 'Industry Movements':                                Industry Departures Hires  Ratio Net change  \
# 0     Information Technology & Services         11     8 -1.375         -3
# 1                 Management Consulting          2     7  3.500          5
# 2                            Automotive          6     2 -3.000         -4
# 3                            Accounting          2     3  1.500          1
# 4                      Higher Education          2     2  1.000          0
# ...                                 ...        ...   ...    ...        ...
# 1094                           Research          0     2  2.000          2
# 1095                             Retail          0     2  2.000          2
# 1096                     Semiconductors          1     1  1.000          0
# 1097              Staffing & Recruiting          0     2  2.000          2
# 1098                 Telecommunications          0     4  4.000          4
#
#      Company_Name
# 0       accenture
# 1       accenture
# 2       accenture
# 3       accenture
# 4       accenture
# ...           ...
# 1094    Vinngroup
# 1095    Vinngroup
# 1096    Vinngroup
# 1097    Vinngroup
# 1098    Vinngroup
#
# [1099 rows x 6 columns], 'Titles':                                          Titles  Employees  1y growth  \
# 0                             Associate Manager         14  -0.066667
# 1                           Strategy Consultant         14   0.000000
# 2                                Senior Manager         12  -0.142857
# 3                  Business Integration Manager         11   0.375000
# 4                            Management Analyst         11   0.222222
# ...                                         ...        ...        ...
# 2726                        Validation Engineer          1        NaN
# 2727                             Vice President          1        NaN
# 2728    Vice President Research And Development          1        NaN
# 2729  Vice President Sales Business Development          1        NaN
# 2730                              Web Developer          1        NaN
#
#       1y hires  Job posts  % of employees    Your % Company_Name  \
# 0            2          0        0.045752  0.000000    accenture
# 1            0          0        0.045752  0.000000    accenture
# 2            0          0        0.039216  0.002095    accenture
# 3            1          0        0.035948  0.000000    accenture
# 4            2          0        0.035948  0.000000    accenture
# ...        ...        ...             ...       ...          ...
# 2726         0          0        0.005556  0.006281    Vinngroup
# 2727         0          0        0.005556  0.001221    Vinngroup
# 2728         0          0        0.005556  0.000000    Vinngroup
# 2729         0          0        0.005556  0.000000    Vinngroup
# 2730         0          0        0.005556  0.000174    Vinngroup
#
#       N Last Year Employee  1 Year Growth
# 0                      NaN      -0.066667
# 1                      NaN       0.000000
# 2                      NaN      -0.142857
# 3                      NaN       0.375000
# 4                      NaN       0.222222
# ...                    ...            ...
# 2726                   1.0       0.000000
# 2727                   1.0       0.000000
# 2728                   1.0       0.000000
# 2729                   1.0       0.000000
# 2730                   1.0       0.000000
#
# [2731 rows x 10 columns], 'Skills':                              Skills  Employees  1y growth  1y hires  \
# 0              Software Development        123  -0.082090        16
# 1                              Java        102  -0.055556        17
# 2     Python (Programming Language)         97  -0.039604        29
# 3                               SQL         89  -0.082474        15
# 4                       Engineering         84   0.012048        15
# ...                             ...        ...        ...       ...
# 5575                           Zoom          1        NaN         0
# 5576                           eSCM          2        NaN         0
# 5577                            iOS          3        NaN         1
# 5578                iOS Development          3        NaN         2
# 5579                         jQuery         12        NaN         2
#
#       Job posts  % of employees    Your % Company_Name  N Last Year Employee  \
# 0             3        0.401961  0.333566    accenture                   NaN
# 1             1        0.333333  0.192529    accenture                   NaN
# 2             0        0.316993  0.264444    accenture                   NaN
# 3             0        0.290850  0.130040    accenture                   NaN
# 4             2        0.274510  0.549660    accenture                   NaN
# ...         ...             ...       ...          ...                   ...
# 5575          0        0.000318  0.000000    Vinngroup                   1.0
# 5576          0        0.000636  0.000000    Vinngroup                   2.0
# 5577          0        0.000955  0.012561    Vinngroup                   2.0
# 5578          0        0.000955  0.012038    Vinngroup                   1.0
# 5579          0        0.003818  0.029658    Vinngroup                  11.0
#
#       1 Year Growth
# 0         -0.082090
# 1         -0.055556
# 2         -0.039604
# 3         -0.082474
# 4          0.012048
# ...             ...
# 5575       0.000000
# 5576       0.000000
# 5577       0.500000
# 5578       2.000000
# 5579       0.090909
#
# [5580 rows x 10 columns], 'Attrition by Functions':                          Function  Attrition  Your attrition  % of employees  \
# 0                     Engineering   0.210526        0.095893        0.209150
# 1          Information Technology   0.179104        0.137625        0.209150
# 2            Business Development   0.052174        0.145985        0.199346
# 3                      Consulting   0.285714        0.148148        0.068627
# 4                      Operations   0.114286        0.165121        0.058824
# ..                            ...        ...             ...             ...
# 132  Customer Success and Support   0.100000        0.125000        0.016287
# 133                      Research   0.125000        0.218905        0.011401
# 134        Information Technology   0.265306        0.137625        0.401639
# 135                   Engineering   0.194444        0.095893        0.286885
# 136                         Sales   0.117647        0.198020        0.147541
#
#      Company_Name  Departures  Average Employee  Attrition by Function
# 0       accenture    4.403165         20.915033               0.210526
# 1       accenture    3.745976         20.915033               0.179104
# 2       accenture    1.040068         19.934641               0.052174
# 3       accenture    1.960784          6.862745               0.285714
# 4       accenture    0.672269          5.882353               0.114286
# ..            ...         ...               ...                    ...
# 132         tieto    0.162866          1.628665               0.100000
# 133         tieto    0.142508          1.140065               0.125000
# 134  togethertech   10.655737         40.163934               0.265306
# 135  togethertech    5.578324         28.688523               0.194444
# 136  togethertech    1.735776         14.754099               0.117647
#
# [137 rows x 8 columns], 'Attrition by Locations':                     Location  Attrition  Your attrition  % of employees  \
# 0                Stockholm     0.173913        0.150495        0.745098
# 1               Gothenburg     0.281690        0.115924        0.111111
# 2                    Malmö     0.162162        0.132964        0.065359
# 3                Stockholm     0.200131        0.150495        0.257606
# 4               Gothenburg     0.179104        0.115924        0.225490
# ..                       ...        ...             ...             ...
# 147                Uppsala     0.098039             NaN        0.042345
# 148  Kalmar, Kalmar , Sweden   0.098765             NaN        0.034202
# 149             Gothenburg     0.131737        0.115924        0.688525
# 150             Gothenburg     0.111280        0.116072        1.875000
# 151              Stockholm     0.050000        0.150495        0.846154
#
#      Company_Name  Departures  Average Employee  Attrition by Locations  \
# 0       accenture   12.958227         74.509805                0.173913
# 1       accenture    3.129891         11.111111                0.281690
# 2       accenture    1.059883          6.535948                0.162162
# 3            afry    5.155499         25.760648                0.200131
# 4            afry    4.038630         22.549020                0.179104
# ..            ...         ...               ...                     ...
# 147         tieto    0.415150          4.234528                0.098039
# 148         tieto    0.337797          3.420195                0.098765
# 149  togethertech    9.070384         68.852460                0.131737
# 150     Vinngroup   10.518293        187.500000                0.056098
# 151     Vinngroup    4.230769         84.615386                0.050000
#
#               City    County Country
# 0      Stockholm        None  Sweden
# 1     Gothenburg        None  Sweden
# 2          Malmö        None  Sweden
# 3      Stockholm        None  Sweden
# 4     Gothenburg        None  Sweden
# ..             ...       ...     ...
# 147      Uppsala        None  Sweden
# 148         Kalmar   Kalmar   Sweden
# 149   Gothenburg        None  Sweden
# 150   Gothenburg        None  Sweden
# 151    Stockholm        None  Sweden
#
# [152 rows x 11 columns], 'Schools':                                     Schools  Employees  1y growth  1y hires  \
# 0         KTH Royal Institute of Technology         76  -0.012987        12
# 1         Chalmers University of Technology         29   0.208333         8
# 2                      Linköping University         28   0.120000         6
# 3                      Stockholm University         26  -0.071429         3
# 4                        Uppsala University         24  -0.076923         3
# ...                                     ...        ...        ...       ...
# 3148  Visvesvaraya Technological University          1        NaN         1
# 3149                       Växjö University          1        NaN         0
# 3150                       Wuhan University          1        NaN         0
# 3151                            YH Akademin          1        NaN         0
# 3152                                   Yrgo          5        NaN         1
#
#       % of employees    Your % Company_Name  N Last Year Employee  \
# 0           0.248366  0.035608    accenture                   NaN
# 1           0.094771  0.307209    accenture                   NaN
# 2           0.091503  0.034910    accenture                   NaN
# 3           0.084967  0.006284    accenture                   NaN
# 4           0.078431  0.015360    accenture                   NaN
# ...              ...       ...          ...                   ...
# 3148        0.004219  0.009944    Vinngroup                   0.0
# 3149        0.004219  0.003140    Vinngroup                   1.0
# 3150        0.004219  0.000174    Vinngroup                   1.0
# 3151        0.004219  0.003838    Vinngroup                   1.0
# 3152        0.021097  0.006281    Vinngroup                   4.0
#
#       1 Year Growth
# 0         -0.012987
# 1          0.208333
# 2          0.120000
# 3         -0.071429
# 4         -0.076923
# ...             ...
# 3148            NaN
# 3149       0.000000
# 3150       0.000000
# 3151       0.000000
# 3152       0.250000
#
# [3153 rows x 9 columns], 'Degrees':                                 Degree   Company  Industry  Your company  \
# 0    Master of Business Administration  0.185841  0.146569      0.060962
# 1                      Master's Degree  0.566372  0.594803      0.614817
# 2                   Associate's Degree  0.004425  0.003654      0.003827
# 3                    Bachelor's Degree  0.225664  0.204628      0.262985
# 4                 Doctor of Philosophy  0.017699  0.050345      0.057408
# ..                                 ...       ...       ...           ...
# 205                 Associate's Degree  0.000000  0.004027      0.003825
# 206                  Bachelor's Degree  0.309859  0.219985      0.262842
# 207               Doctor of Philosophy  0.085928  0.100428      0.057377
# 208  Master of Business Administration  0.031445  0.075258      0.060929
# 209                    Master's Degree  0.510269  0.600302      0.615027
#
#     Company_Name
# 0      accenture
# 1      accenture
# 2      accenture
# 3      accenture
# 4      accenture
# ..           ...
# 205    Vinngroup
# 206    Vinngroup
# 207    Vinngroup
# 208    Vinngroup
# 209    Vinngroup
#
# [210 rows x 5 columns], 'Fields of Study':                               Fields of study  Employees  1y growth  1y hires  \
# 0                      Information Technology         49  -0.057692         5
# 1                            Computer Science         48   0.021277         9
# 2                       Computational Science         44   0.000000         7
# 3           Engineering/Industrial Management         42   0.235294        13
# 4                      Mechanical Engineering         23   0.000000         5
# ...                                       ...        ...        ...       ...
# 3033          Swedish Language and Literature          1        NaN         1
# 3034               Systems Science and Theory          1        NaN         0
# 3035           Telecommunications Engineering          1        NaN         1
# 3036     Theoretical and Mathematical Physics          1        NaN         1
# 3037  Web/Multimedia Management and Webmaster          3        NaN         2
#
#       % of employees    Your % Company_Name  N Last Year Employee  \
# 0           0.160131  0.043638    accenture                   NaN
# 1           0.156863  0.084133    accenture                   NaN
# 2           0.143791  0.071740    accenture                   NaN
# 3           0.137255  0.015011    accenture                   NaN
# 4           0.075163  0.144702    accenture                   NaN
# ...              ...       ...          ...                   ...
# 3033        0.003115  0.001919    Vinngroup                   0.0
# 3034        0.003115  0.001047    Vinngroup                   1.0
# 3035        0.003115  0.005583    Vinngroup                   0.0
# 3036        0.003115  0.001047    Vinngroup                   0.0
# 3037        0.009346  0.002791    Vinngroup                   1.0
#
#       1 Year Growth
# 0         -0.057692
# 1          0.021277
# 2          0.000000
# 3          0.235294
# 4          0.000000
# ...             ...
# 3033            NaN
# 3034       0.000000
# 3035            NaN
# 3036            NaN
# 3037       2.000000
#
# [3038 rows x 9 columns]}

# %% [markdown]
# ### Process Description for Data Preprocessing
#
# #### Defining Sheets to Process
# - The script defines a list of sheet names (`sheets_to_process`) that are to be processed. This includes 'Locations', 'Titles', 'Skills', 'Schools', and 'Fields of Study'.
#
# #### Iterative Sheet Processing
# - The script iterates through each sheet name in the list.
# - It checks if the sheet exists in the `final_result` dictionary.
#
# #### Filling Missing Values
# - For sheets present in `final_result`, the script fills missing values in the '1 Year Growth' column with corresponding values from the '1y growth' column.
# - This step is crucial for maintaining data integrity and ensuring completeness in key growth-related metrics.
#
# #### Handling Absent Sheets
# - If any of the specified sheets are not found in `final_result`, the script prints a message indicating the absence of that sheet.
#
# #### Updating and Printing Final Result
# - The script then prints the updated `final_result` dictionary, showcasing the changes made.

# %% [markdown]
# # Exporting Processed Data to a Single Excel File

# %%
with pd.ExcelWriter(output_path+"Combine231113.xlsx") as writer:
    for sheet_slected in initial_sheets_list:
        final_result[sheet_slected].to_excel(writer, sheet_name=sheet_slected, index=False)

# %% [markdown]
# ### Key Steps in Exporting Processed Data to Excel
#
# #### Initialization of Excel Writer
# - The `pd.ExcelWriter` is used to create an Excel file at the specified `output_path`. This allows for writing multiple DataFrames to a single Excel file across different sheets.
#
# #### Iterating and Writing Data to Sheets
# - The script iterates through each sheet name stored in `initial_sheets_list`.
# - For each sheet, the corresponding DataFrame from `final_result` is written to the Excel file using the `to_excel` method.
# - The parameter `index=False` ensures that DataFrame indices are not included in the output file, leading to cleaner data presentation.
